# %% [markdown]
# # Apertura de las bases de datos.

# %% [markdown]
# ## Importación de librerías.

# %% [markdown]
# ### Bibliotecas.

# %%
# Se descargan las librerías necesarias.

# ! pip install openpyxl
# ! pip install scipy}
# ! pip install seaborn

# %%
# Se importan las librerías a utilizar.
import pandas as pd
import numpy as np
import scipy.stats as stats 
import seaborn as sns
import matplotlib.pyplot as plt
import warnings

# %% [markdown]
# ### Ruta

# %%
# Se extraen la rutas de los archivos
ruta_homicidios = "../Data/Originales/homicidios.xlsx"
ruta_lesiones = "../Data/Originales/lesiones.xlsx"

# %% [markdown]
# ### Warnings

# %%
# Se filtran warnings no necesarios o revisados.

# FutureWarning.
warnings.filterwarnings("ignore", category=FutureWarning)

# %% [markdown]
# # Revisión de las bases de datos

# %% [markdown]
# ## Homicidios - hechos

# %% [markdown]
# ### Revisión de la base de datos.

# %%
# Se convierte la base de datos en un dataframe de pandas y se observa la composición de las primeras líneas de la base de datos.
hechos = pd.read_excel(ruta_homicidios, sheet_name= "HECHOS")
hechos.head()
# Out:
#           ID  N_VICTIMAS      FECHA  AAAA  MM  DD      HORA HH  \
# 0  2016-0001           1 2016-01-01  2016   1   1  04:00:00  4
# 1  2016-0002           1 2016-01-02  2016   1   2  01:15:00  1
# 2  2016-0003           1 2016-01-03  2016   1   3  07:00:00  7
# 3  2016-0004           1 2016-01-10  2016   1  10  00:00:00  0
# 4  2016-0005           1 2016-01-21  2016   1  21  05:20:00  5
#
#                              LUGAR_DEL_HECHO TIPO_DE_CALLE  ...  Altura  \
# 0  AV PIEDRA BUENA Y AV FERNANDEZ DE LA CRUZ       AVENIDA  ...     NaN
# 1          AV GRAL PAZ  Y AV DE LOS CORRALES      GRAL PAZ  ...     NaN
# 2                         AV ENTRE RIOS 2034       AVENIDA  ...  2034.0
# 3      AV LARRAZABAL Y GRAL VILLEGAS CONRADO       AVENIDA  ...     NaN
# 4  AV SAN JUAN Y PRESIDENTE LUIS SAENZ PEÑA        AVENIDA  ...     NaN
#
#                                  Cruce  \
# 0  FERNANDEZ DE LA CRUZ, F., GRAL. AV.
# 1                  DE LOS CORRALES AV.
# 2                                  NaN
# 3             VILLEGAS, CONRADO, GRAL.
# 4              SAENZ PE?A, LUIS, PRES.
#
#                                Dirección Normalizada COMUNA  \
# 0  PIEDRA BUENA AV. y FERNANDEZ DE LA CRUZ, F., G...      8
# 1               PAZ, GRAL. AV. y DE LOS CORRALES AV.      9
# 2                                ENTRE RIOS AV. 2034      1
# 3          LARRAZABAL AV. y VILLEGAS, CONRADO, GRAL.      8
# 4            SAN JUAN AV. y SAENZ PEÃ‘A, LUIS, PRES.      1
#
#                                  XY (CABA)         pos x         pos y  \
# 0    Point (98896.78238426 93532.43437792)  -58.47533969  -34.68757022
# 1    Point (95832.05571093 95505.41641999)  -58.50877521  -34.66977709
# 2   Point (106684.29090040 99706.57687843)  -58.39040293  -34.63189362
# 3    Point (99840.65224780 94269.16534422)  -58.46503904  -34.68092974
# 4  Point (106980.32827929 100752.16915795)  -58.38718297  -34.62246630
#
#     PARTICIPANTES VICTIMA    ACUSADO
# 0       MOTO-AUTO    MOTO       AUTO
# 1  AUTO-PASAJEROS    AUTO  PASAJEROS
# 2       MOTO-AUTO    MOTO       AUTO
# 3         MOTO-SD    MOTO         SD
# 4  MOTO-PASAJEROS    MOTO  PASAJEROS
#
# [5 rows x 21 columns]

# %%
# Se observa la composición de las variables de la base de datos y el tipo de dato. 
hechos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 696 entries, 0 to 695
# Data columns (total 21 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   ID                     696 non-null    object
#  1   N_VICTIMAS             696 non-null    int64
#  2   FECHA                  696 non-null    datetime64[ns]
#  3   AAAA                   696 non-null    int64
#  4   MM                     696 non-null    int64
#  5   DD                     696 non-null    int64
#  6   HORA                   696 non-null    object
#  7   HH                     696 non-null    object
#  8   LUGAR_DEL_HECHO        696 non-null    object
#  9   TIPO_DE_CALLE          696 non-null    object
#  10  Calle                  695 non-null    object
#  11  Altura                 129 non-null    float64
#  12  Cruce                  525 non-null    object
#  13  Dirección Normalizada  688 non-null    object
#  14  COMUNA                 696 non-null    int64
#  15  XY (CABA)              696 non-null    object
#  16  pos x                  696 non-null    object
#  17  pos y                  696 non-null    object
#  18  PARTICIPANTES          696 non-null    object
#  19  VICTIMA                696 non-null    object
#  20  ACUSADO                696 non-null    object
# dtypes: datetime64[ns](1), float64(1), int64(5), object(14)
# memory usage: 114.3+ KB

# %%
# Como algunas de las columnas no retornan el tipo de dato que se esperaría, se decide revisar que el formato esté correctamente formateado. 
print(f"El tipo de dato de la columna 'hora' es: {type(hechos.loc[1,"HORA"])}")
print(f"El tipo de dato de la columna 'pox x' es: {type(hechos.loc[1,"pos x"])}")
print(f"El tipo de dato de la columna 'pos y' es: {type(hechos.loc[1,"pos y"])}")
# Out:
# El tipo de dato de la columna 'hora' es: <class 'datetime.time'>
# El tipo de dato de la columna 'pox x' es: <class 'str'>
# El tipo de dato de la columna 'pos y' es: <class 'str'>

# %%
# Es de notar que tanto en "Pos X" como en "Pos Y" hay datos que no presentan información, sino únicamente un "." (punto) sin información.
hechos[hechos["pos x"] == "."]
# Out:
#             ID  N_VICTIMAS      FECHA  AAAA  MM  DD      HORA  HH  \
# 38   2016-0052           1 2016-04-20  2016   4  20  20:00:00  20
# 106  2016-0136           1 2016-10-25  2016  10  25  00:00:00   0
# 119  2016-0151           1 2016-11-18  2016  11  18  20:35:00  20
# 139  2016-0174           1 2016-12-27  2016  12  27  00:00:00   0
# 176  2017-0042           1 2017-04-10  2017   4  10  09:00:00   9
# 180  2017-0050           2 2017-04-28  2017   4  28  11:08:08  11
# 181  2017-0051           1 2017-05-01  2017   5   1  03:47:47   3
# 256  2017-0140           1 2017-11-19  2017  11  19  23:22:17  23
# 313  2018-0039           1 2018-04-21  2018   4  21  22:15:00  22
# 546  2020-0026           1 2020-05-17  2020   5  17  06:40:00   6
# 559  2020-0039           1 2020-09-01  2020   9   1  19:17:42  19
# 621  2021-0023           1 2021-03-01  2021   3   1  09:20:00   9
#
#                              LUGAR_DEL_HECHO TIPO_DE_CALLE  ... Altura  Cruce  \
# 38                AUTOPISTA LUGONES PK 10000     AUTOPISTA  ...    NaN    NaN
# 106         AU BUENOS AIRES - LA PLATA KM. 4     AUTOPISTA  ...    NaN    NaN
# 119                                       SD         CALLE  ...    NaN    NaN
# 139                     AUTOPISTA 25 DE MAYO     AUTOPISTA  ...    NaN    NaN
# 176            AV. LEOPOLDO LUGONES PKM 6900      GRAL PAZ  ...    NaN    NaN
# 180  AU PERITO MORENO Y RAMAL ENLACE AU1/AU6     AUTOPISTA  ...    NaN    NaN
# 181                       AU DELLEPIANE 2400     AUTOPISTA  ...    NaN    NaN
# 256              AU ARTURO FRONDIZI PKM 3100     AUTOPISTA  ...    NaN    NaN
# 313                 AUTOPISTA LUGONES KM 4.7     AUTOPISTA  ...    NaN    NaN
# 546             LUGONES, LEOPOLDO AV. KM 6,1     AUTOPISTA  ...    NaN    NaN
# 559                          MURGUIONDO 2700         CALLE  ...    NaN    NaN
# 621         AU BUENOS AIRES LA PLATA  KM 4,5     AUTOPISTA  ...    NaN    NaN
#
#                           Dirección Normalizada COMUNA    XY (CABA) pos x  \
# 38                                          NaN     13  Point (. .)     .
# 106                                         NaN      4  Point (. .)     .
# 119                                         NaN      0  Point (. .)     .
# 139                        AUTOPISTA 25 DE MAYO      0  Point (. .)     .
# 176                       LUGONES, LEOPOLDO AV.     14  Point (. .)     .
# 180                                         NaN      9  Point (. .)     .
# 181                                         NaN      7  Point (. .)     .
# 256  AUTOPISTA 1 SUR PRESIDENTE ARTURO FRONDIZI      4  Point (. .)     .
# 313                                         NaN     14  Point (. .)     .
# 546                                         NaN     14  Point (. .)     .
# 559                                  MURGUIONDO      9  Point (. .)     .
# 621                                         NaN      4  Point (. .)     .
#
#     pos y     PARTICIPANTES VICTIMA      ACUSADO
# 38      .           MOTO-SD    MOTO           SD
# 106     .       MOTO-CARGAS    MOTO       CARGAS
# 119     .         PEATON-SD  PEATON           SD
# 139     .             SD-SD      SD           SD
# 176     .       MOTO-CARGAS    MOTO       CARGAS
# 180     .       MOTO-CARGAS    MOTO       CARGAS
# 181     .         AUTO-AUTO    AUTO         AUTO
# 256     .    MOTO-PASAJEROS    MOTO    PASAJEROS
# 313     .       PEATON-AUTO  PEATON         AUTO
# 546     .  MOTO-OBJETO FIJO    MOTO  OBJETO FIJO
# 559     .     PEATON-CARGAS  PEATON       CARGAS
# 621     .       MOTO-CARGAS    MOTO       CARGAS
#
# [12 rows x 21 columns]

# %%
# Como las columnas "pos x" y "pos y" aparecen como tipo string, se convierten a tipo float, corrigiendo los valores nulos.
hechos["pos x"] = pd.to_numeric(hechos["pos x"], errors='coerce')
hechos["pos y"] = pd.to_numeric(hechos["pos y"], errors='coerce')

# %%
# Se observa el resultado para los datos nulos.
hechos[hechos["pos x"].isna()]
# Out:
#             ID  N_VICTIMAS      FECHA  AAAA  MM  DD      HORA  HH  \
# 38   2016-0052           1 2016-04-20  2016   4  20  20:00:00  20
# 106  2016-0136           1 2016-10-25  2016  10  25  00:00:00   0
# 119  2016-0151           1 2016-11-18  2016  11  18  20:35:00  20
# 139  2016-0174           1 2016-12-27  2016  12  27  00:00:00   0
# 176  2017-0042           1 2017-04-10  2017   4  10  09:00:00   9
# 180  2017-0050           2 2017-04-28  2017   4  28  11:08:08  11
# 181  2017-0051           1 2017-05-01  2017   5   1  03:47:47   3
# 256  2017-0140           1 2017-11-19  2017  11  19  23:22:17  23
# 313  2018-0039           1 2018-04-21  2018   4  21  22:15:00  22
# 546  2020-0026           1 2020-05-17  2020   5  17  06:40:00   6
# 559  2020-0039           1 2020-09-01  2020   9   1  19:17:42  19
# 621  2021-0023           1 2021-03-01  2021   3   1  09:20:00   9
#
#                              LUGAR_DEL_HECHO TIPO_DE_CALLE  ... Altura  Cruce  \
# 38                AUTOPISTA LUGONES PK 10000     AUTOPISTA  ...    NaN    NaN
# 106         AU BUENOS AIRES - LA PLATA KM. 4     AUTOPISTA  ...    NaN    NaN
# 119                                       SD         CALLE  ...    NaN    NaN
# 139                     AUTOPISTA 25 DE MAYO     AUTOPISTA  ...    NaN    NaN
# 176            AV. LEOPOLDO LUGONES PKM 6900      GRAL PAZ  ...    NaN    NaN
# 180  AU PERITO MORENO Y RAMAL ENLACE AU1/AU6     AUTOPISTA  ...    NaN    NaN
# 181                       AU DELLEPIANE 2400     AUTOPISTA  ...    NaN    NaN
# 256              AU ARTURO FRONDIZI PKM 3100     AUTOPISTA  ...    NaN    NaN
# 313                 AUTOPISTA LUGONES KM 4.7     AUTOPISTA  ...    NaN    NaN
# 546             LUGONES, LEOPOLDO AV. KM 6,1     AUTOPISTA  ...    NaN    NaN
# 559                          MURGUIONDO 2700         CALLE  ...    NaN    NaN
# 621         AU BUENOS AIRES LA PLATA  KM 4,5     AUTOPISTA  ...    NaN    NaN
#
#                           Dirección Normalizada COMUNA    XY (CABA) pos x  \
# 38                                          NaN     13  Point (. .)   NaN
# 106                                         NaN      4  Point (. .)   NaN
# 119                                         NaN      0  Point (. .)   NaN
# 139                        AUTOPISTA 25 DE MAYO      0  Point (. .)   NaN
# 176                       LUGONES, LEOPOLDO AV.     14  Point (. .)   NaN
# 180                                         NaN      9  Point (. .)   NaN
# 181                                         NaN      7  Point (. .)   NaN
# 256  AUTOPISTA 1 SUR PRESIDENTE ARTURO FRONDIZI      4  Point (. .)   NaN
# 313                                         NaN     14  Point (. .)   NaN
# 546                                         NaN     14  Point (. .)   NaN
# 559                                  MURGUIONDO      9  Point (. .)   NaN
# 621                                         NaN      4  Point (. .)   NaN
#
#      pos y     PARTICIPANTES VICTIMA      ACUSADO
# 38     NaN           MOTO-SD    MOTO           SD
# 106    NaN       MOTO-CARGAS    MOTO       CARGAS
# 119    NaN         PEATON-SD  PEATON           SD
# 139    NaN             SD-SD      SD           SD
# 176    NaN       MOTO-CARGAS    MOTO       CARGAS
# 180    NaN       MOTO-CARGAS    MOTO       CARGAS
# 181    NaN         AUTO-AUTO    AUTO         AUTO
# 256    NaN    MOTO-PASAJEROS    MOTO    PASAJEROS
# 313    NaN       PEATON-AUTO  PEATON         AUTO
# 546    NaN  MOTO-OBJETO FIJO    MOTO  OBJETO FIJO
# 559    NaN     PEATON-CARGAS  PEATON       CARGAS
# 621    NaN       MOTO-CARGAS    MOTO       CARGAS
#
# [12 rows x 21 columns]

# %%
# Se transforman los nombres para "pos x" y "pos y" por "latitud" y "longitud"
hechos.rename(columns={"pos x":"longitud","pos y":"latitud"},inplace=True)

# %%
# Se revisan si existen filas duplicadas.
duplicados = hechos.duplicated()
print(hechos[duplicados])

# En este caso no se observan filas completas duplicadas, por lo que se decide revisar si existen ID duplicados. 
id_duplicados = hechos.duplicated(subset="ID")
print(hechos[id_duplicados])

# En este caso no se observan que existan filas de hechos duplicados.
# Out:
# Empty DataFrame
# Columns: [ID, N_VICTIMAS, FECHA, AAAA, MM, DD, HORA, HH, LUGAR_DEL_HECHO, TIPO_DE_CALLE, Calle, Altura, Cruce, Dirección Normalizada, COMUNA, XY (CABA), longitud, latitud, PARTICIPANTES, VICTIMA, ACUSADO]
# Index: []
#
# [0 rows x 21 columns]
# Empty DataFrame
# Columns: [ID, N_VICTIMAS, FECHA, AAAA, MM, DD, HORA, HH, LUGAR_DEL_HECHO, TIPO_DE_CALLE, Calle, Altura, Cruce, Dirección Normalizada, COMUNA, XY (CABA), longitud, latitud, PARTICIPANTES, VICTIMA, ACUSADO]
# Index: []
#
# [0 rows x 21 columns]

# %%
# Se observa la distribución de la base de datos.
hechos.describe()
# Out:
#        N_VICTIMAS                          FECHA         AAAA          MM  \
# count  696.000000                            696   696.000000  696.000000
# mean     1.030172  2018-09-14 05:12:24.827586048  2018.188218    6.692529
# min      1.000000            2016-01-01 00:00:00  2016.000000    1.000000
# 25%      1.000000            2017-04-02 12:00:00  2017.000000    4.000000
# 50%      1.000000            2018-07-12 12:00:00  2018.000000    7.000000
# 75%      1.000000            2020-01-04 06:00:00  2020.000000   10.000000
# max      3.000000            2021-12-30 00:00:00  2021.000000   12.000000
# std      0.179393                            NaN     1.683754    3.571309
#
#                DD        Altura      COMUNA    longitud     latitud
# count  696.000000    129.000000  696.000000  684.000000  684.000000
# mean    15.936782   3336.635659    7.425287  -58.441545  -34.619632
# min      1.000000     30.000000    0.000000  -58.529942  -34.705250
# 25%      9.000000   1359.000000    4.000000  -58.476218  -34.643689
# 50%     16.000000   2551.000000    8.000000  -58.444513  -34.622928
# 75%     23.000000   4500.000000   11.000000  -58.401841  -34.596799
# max     31.000000  16080.000000   15.000000  -58.356082  -34.534654
# std      8.639646   3060.641793    4.387050    0.046144    0.035289

# %% [markdown]
# De este primer vistado de los resultados de las columnas, salta a la vista que en la columna "COMUNA" se presentan datos en 0, los cuales al ser observados (véase la celda de código de abajo), son dos datos cuya información no aparece completa. Se deciden eliminar estos dos registros ya que al no tener tampoco información en las columnas "Latitud" y "Longitud" no podría ser usado posteriormente para análisis.

# %%
# Se observan los datos que cumplen con la condición de tener la comuna en 0.
hechos[hechos["COMUNA"] == 0]
# Out:
#             ID  N_VICTIMAS      FECHA  AAAA  MM  DD      HORA  HH  \
# 119  2016-0151           1 2016-11-18  2016  11  18  20:35:00  20
# 139  2016-0174           1 2016-12-27  2016  12  27  00:00:00   0
#
#           LUGAR_DEL_HECHO TIPO_DE_CALLE  ... Altura  Cruce  \
# 119                    SD         CALLE  ...    NaN    NaN
# 139  AUTOPISTA 25 DE MAYO     AUTOPISTA  ...    NaN    NaN
#
#     Dirección Normalizada COMUNA    XY (CABA) longitud  latitud  \
# 119                   NaN      0  Point (. .)      NaN      NaN
# 139  AUTOPISTA 25 DE MAYO      0  Point (. .)      NaN      NaN
#
#      PARTICIPANTES VICTIMA ACUSADO
# 119      PEATON-SD  PEATON      SD
# 139          SD-SD      SD      SD
#
# [2 rows x 21 columns]

# %%
# Se filtran estos datos del data set para tener aquellos que no presentan esta condición.
hechos = hechos[hechos["COMUNA"] != 0]

# %%
# Se observan datos resultantes. 
hechos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 694 entries, 0 to 695
# Data columns (total 21 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   ID                     694 non-null    object
#  1   N_VICTIMAS             694 non-null    int64
#  2   FECHA                  694 non-null    datetime64[ns]
#  3   AAAA                   694 non-null    int64
#  4   MM                     694 non-null    int64
#  5   DD                     694 non-null    int64
#  6   HORA                   694 non-null    object
#  7   HH                     694 non-null    object
#  8   LUGAR_DEL_HECHO        694 non-null    object
#  9   TIPO_DE_CALLE          694 non-null    object
#  10  Calle                  694 non-null    object
#  11  Altura                 129 non-null    float64
#  12  Cruce                  525 non-null    object
#  13  Dirección Normalizada  687 non-null    object
#  14  COMUNA                 694 non-null    int64
#  15  XY (CABA)              694 non-null    object
#  16  longitud               684 non-null    float64
#  17  latitud                684 non-null    float64
#  18  PARTICIPANTES          694 non-null    object
#  19  VICTIMA                694 non-null    object
#  20  ACUSADO                694 non-null    object
# dtypes: datetime64[ns](1), float64(3), int64(5), object(12)
# memory usage: 119.3+ KB

# %% [markdown]
# Existen datos nulos en Altura y Cruce, pero no se trabajan directamenteo por:
# - En el caso de **Altura**, los datos nulos no resultan un impedimento ya que se puede identificar el punto donde ocurrió el accidente gracias a los datos en Latitud y Longitud.
# - En el caso de **Cruce**, se entiende que aquellos datos nulos son aquellos que no corresponden a un cruce (de acuerdo a la información proporcionado por el diccionario).
#
# Para el caso de PARTICIPANTES, se observan que existen datos donde tanto el conductor como la víctima se encuentran sin identificar. Se observa su incidencia a continuación:

# %%
# Se filtra la base para observar la ocurrencia de este tipo de dato en la columna de participantes.
print(hechos[hechos["PARTICIPANTES"] == "SD-SD"])

# Sólo se presentan 4 columnas de datos de este tipo, por lo que se considera que no afectan la base y se eliminan.
hechos = hechos[hechos["PARTICIPANTES"] != "SD-SD"]
# Out:
#             ID  N_VICTIMAS      FECHA  AAAA  MM  DD      HORA  HH  \
# 35   2016-0049           1 2016-04-17  2016   4  17  00:00:00   0
# 76   2016-0101           1 2016-08-07  2016   8   7  19:42:00  19
# 92   2016-0119           1 2016-09-04  2016   9   4  06:40:00   6
# 201  2017-0074           1 2017-06-04  2017   6   4  12:50:00  12
#
#                                        LUGAR_DEL_HECHO TIPO_DE_CALLE  ...  \
# 35   AUTOPISTA 1 SUR PRESIDENTE ARTURO FRONDIZI KM....     AUTOPISTA  ...
# 76                          AV GRAL PAZ Y JORGE CHAVEZ      GRAL PAZ  ...
# 92               CRISOLOGO LARRALDE Y AVDA TRIUNVIRATO       AVENIDA  ...
# 201                                          CASCO 133         CALLE  ...
#
#     Altura            Cruce                       Dirección Normalizada  \
# 35     NaN              NaN  AUTOPISTA 1 SUR PRESIDENTE ARTURO FRONDIZI
# 76     NaN    CHAVEZ, JORGE              PAZ, GRAL. AV. y CHAVEZ, JORGE
# 92     NaN  TRIUNVIRATO AV.   LARRALDE, CRISOLOGO AV. y TRIUNVIRATO AV.
# 201  133.0              NaN                                   CASCO 133
#
#     COMUNA                               XY (CABA)   longitud    latitud  \
# 35       4                             Point (. .) -58.377146 -34.636575
# 76       9   Point (93946.81673714 97681.68907836) -58.529329 -34.650150
# 92      12  Point (96944.69676081 107291.52292157) -58.496592 -34.563536
# 201      9   Point (94281.31244858 99043.29027489) -58.525671 -34.637878
#
#      PARTICIPANTES VICTIMA ACUSADO
# 35           SD-SD      SD      SD
# 76           SD-SD      SD      SD
# 92           SD-SD      SD      SD
# 201          SD-SD      SD      SD
#
# [4 rows x 21 columns]

# %%
# Se transforman todos los datos marcados como "SD" a dato nulo, ya que no proporcionan información al análisis.
hechos.replace("SD",np.nan,inplace=True)

# %%
# Se elimina la columna "XY CABA" ya que la información que proporciona se encuentra en longitud y latitud
hechos.drop(columns=["XY (CABA)"],inplace=True)

# %%
# por redundancia o información no necesaria para el análisis de los datos se elimina la columnna de "HH", "LUGAR_DEL_HECHO", "Calle" y "Altura"
hechos.drop(columns=["HH","LUGAR_DEL_HECHO","Calle", "Altura"],inplace=True)

# %%
# Se crea la columna "cruce_r" con "Es Cruce"/"No es cruce" basado en la presencia de NaN en "cruce".
hechos.insert(9,'cruce_r', hechos['Cruce'].apply(lambda x: "No es cruce" if pd.isna(x) else "Es cruce"))

# %%
# Se eliminan las filas en NAN para "longitud", "latitud","VICTIMA"	y"ACUSADO"
hechos.dropna(subset=["longitud", "latitud","VICTIMA","ACUSADO"],inplace=True)

# %%
# Se hace una revisión de los datos en fecha.
hechos["fecha_completa"] = pd.to_datetime(hechos["AAAA"].astype(str)+hechos["MM"].astype(str)+hechos["DD"].astype(str)+" "+hechos["HORA"].astype(str), format="%Y%m%d %H:%M:%S", errors='coerce')
hechos["fecha_revisada"] = pd.to_datetime(hechos["FECHA"], errors='coerce')
valores_problematicos = hechos[hechos["fecha_completa"].isnull() | hechos["fecha_revisada"].isnull()]
valores_problematicos
# Out:
#             ID  N_VICTIMAS      FECHA  AAAA  MM  DD                 HORA  \
# 441  2019-0024           1 2019-03-19  2019   3  19  1900-01-14 07:12:00
# 496  2019-0080           1 2019-09-17  2019   9  17  1900-01-04 18:40:00
# 518  2019-0103           1 2019-12-18  2019  12  18                  NaN
#
#     TIPO_DE_CALLE           Cruce      cruce_r         Dirección Normalizada  \
# 441       AVENIDA             NaN  No es cruce  ANTARTIDA ARGENTINA AV. 1325
# 496      GRAL PAZ  PAZ, GRAL. AV.     Es cruce  CABILDO AV. y PAZ, GRAL. AV.
# 518      GRAL PAZ          GRIVEO     Es cruce       PAZ, GRAL. AV. y GRIVEO
#
#      COMUNA   longitud    latitud PARTICIPANTES VICTIMA ACUSADO  \
# 441       1 -58.372081 -34.585420   MOTO-CARGAS    MOTO  CARGAS
# 496      13 -58.476178 -34.538257   PEATON-MOTO  PEATON    MOTO
# 518      11 -58.521694 -34.594716     MOTO-MOTO    MOTO    MOTO
#
#     fecha_completa fecha_revisada
# 441            NaT     2019-03-19
# 496            NaT     2019-09-17
# 518            NaT     2019-12-18

# %%
# Se corrigen los valores que cuentan con la hora 
hechos.at[441,"fecha_completa"] = pd.to_datetime("2019-03-19 07:12:00")
hechos.at[441,"HORA"] = "07:12:00"
hechos.at[496,"fecha_completa"] = pd.to_datetime("2019-09-17 18:40:00")
hechos.at[496,"HORA"] = "18:40:00"

# %%
# Se elimina el valor nulo.
hechos.dropna(subset="HORA",inplace=True)

# %%
# Se elimina la fecha antigua y se reemplaza.
hechos.drop(columns="FECHA",inplace=True)
hechos.rename(columns={"fecha_revisada":"FECHA"},inplace=True)

# %%
hechos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 659 entries, 0 to 695
# Data columns (total 18 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   ID                     659 non-null    object
#  1   N_VICTIMAS             659 non-null    int64
#  2   AAAA                   659 non-null    int64
#  3   MM                     659 non-null    int64
#  4   DD                     659 non-null    int64
#  5   HORA                   659 non-null    object
#  6   TIPO_DE_CALLE          659 non-null    object
#  7   Cruce                  505 non-null    object
#  8   cruce_r                659 non-null    object
#  9   Dirección Normalizada  659 non-null    object
#  10  COMUNA                 659 non-null    int64
#  11  longitud               659 non-null    float64
#  12  latitud                659 non-null    float64
#  13  PARTICIPANTES          659 non-null    object
#  14  VICTIMA                659 non-null    object
#  15  ACUSADO                659 non-null    object
#  16  fecha_completa         659 non-null    datetime64[ns]
#  17  FECHA                  659 non-null    datetime64[ns]
# dtypes: datetime64[ns](2), float64(2), int64(5), object(9)
# memory usage: 97.8+ KB

# %%
# Se reordenan las columnas en el dataframe
orden = ['ID', 'N_VICTIMAS', 'fecha_completa','FECHA','AAAA', 'MM', 'DD', 'HORA', 'TIPO_DE_CALLE', 'Cruce',
       'cruce_r', 'Dirección Normalizada', 'COMUNA', 'longitud', 'latitud',
       'PARTICIPANTES', 'VICTIMA', 'ACUSADO'] # Se define el orden de las columnas.

hechos = hechos.reindex(columns=orden) # Se reordenan las columnas a partir del orden establecido.

# %%
# Se revisa la información obtenida hasta el momento.
hechos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 659 entries, 0 to 695
# Data columns (total 18 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   ID                     659 non-null    object
#  1   N_VICTIMAS             659 non-null    int64
#  2   fecha_completa         659 non-null    datetime64[ns]
#  3   FECHA                  659 non-null    datetime64[ns]
#  4   AAAA                   659 non-null    int64
#  5   MM                     659 non-null    int64
#  6   DD                     659 non-null    int64
#  7   HORA                   659 non-null    object
#  8   TIPO_DE_CALLE          659 non-null    object
#  9   Cruce                  505 non-null    object
#  10  cruce_r                659 non-null    object
#  11  Dirección Normalizada  659 non-null    object
#  12  COMUNA                 659 non-null    int64
#  13  longitud               659 non-null    float64
#  14  latitud                659 non-null    float64
#  15  PARTICIPANTES          659 non-null    object
#  16  VICTIMA                659 non-null    object
#  17  ACUSADO                659 non-null    object
# dtypes: datetime64[ns](2), float64(2), int64(5), object(9)
# memory usage: 97.8+ KB

# %%
# Y se observa la relación de los datos.
hechos.describe()
# Out:
#        N_VICTIMAS                 fecha_completa  \
# count  659.000000                            659
# mean     1.030349  2018-10-20 10:12:17.044006144
# min      1.000000            2016-01-01 04:00:00
# 25%      1.000000            2017-05-21 10:30:00
# 50%      1.000000            2018-08-17 17:56:00
# 75%      1.000000            2020-02-10 08:37:00
# max      3.000000            2021-12-30 00:43:00
# std      0.180311                            NaN
#
#                                FECHA         AAAA          MM          DD  \
# count                            659   659.000000  659.000000  659.000000
# mean   2018-10-02 20:30:13.657056256  2018.239757    6.682853   16.044006
# min              2016-01-01 00:00:00  2016.000000    1.000000    1.000000
# 25%              2017-05-08 00:00:00  2017.000000    4.000000    9.000000
# 50%              2018-08-01 00:00:00  2018.000000    7.000000   16.000000
# 75%              2020-01-23 12:00:00  2020.000000   10.000000   23.000000
# max              2021-12-30 00:00:00  2021.000000   12.000000   31.000000
# std                              NaN     1.679538    3.580748    8.646179
#
#            COMUNA    longitud     latitud
# count  659.000000  659.000000  659.000000
# mean     7.371775  -58.440517  -34.619420
# min      1.000000  -58.529942  -34.705250
# 25%      4.000000  -58.474817  -34.642949
# 50%      8.000000  -58.443621  -34.622603
# 75%     11.000000  -58.400496  -34.596991
# max     15.000000  -58.356082  -34.534654
# std      4.404666    0.045804    0.034775

# %%
# Se revisa el dataframe obtenido.
hechos.head()
# Out:
#           ID  N_VICTIMAS      fecha_completa      FECHA  AAAA  MM  DD  \
# 0  2016-0001           1 2016-01-01 04:00:00 2016-01-01  2016   1   1
# 1  2016-0002           1 2016-01-02 01:15:00 2016-01-02  2016   1   2
# 2  2016-0003           1 2016-01-03 07:00:00 2016-01-03  2016   1   3
# 4  2016-0005           1 2016-12-01 05:20:00 2016-01-21  2016   1  21
# 5  2016-0008           1 2016-12-04 18:30:00 2016-01-24  2016   1  24
#
#        HORA TIPO_DE_CALLE                                Cruce      cruce_r  \
# 0  04:00:00       AVENIDA  FERNANDEZ DE LA CRUZ, F., GRAL. AV.     Es cruce
# 1  01:15:00      GRAL PAZ                  DE LOS CORRALES AV.     Es cruce
# 2  07:00:00       AVENIDA                                  NaN  No es cruce
# 4  05:20:00       AVENIDA              SAENZ PE?A, LUIS, PRES.     Es cruce
# 5  18:30:00       AVENIDA                         ESCALADA AV.     Es cruce
#
#                                Dirección Normalizada  COMUNA   longitud  \
# 0  PIEDRA BUENA AV. y FERNANDEZ DE LA CRUZ, F., G...       8 -58.475340
# 1               PAZ, GRAL. AV. y DE LOS CORRALES AV.       9 -58.508775
# 2                                ENTRE RIOS AV. 2034       1 -58.390403
# 4            SAN JUAN AV. y SAENZ PEÃ‘A, LUIS, PRES.       1 -58.387183
# 5                   27 DE FEBRERO AV. y ESCALADA AV.       8 -58.444513
#
#      latitud     PARTICIPANTES VICTIMA      ACUSADO
# 0 -34.687570         MOTO-AUTO    MOTO         AUTO
# 1 -34.669777    AUTO-PASAJEROS    AUTO    PASAJEROS
# 2 -34.631894         MOTO-AUTO    MOTO         AUTO
# 4 -34.622466    MOTO-PASAJEROS    MOTO    PASAJEROS
# 5 -34.684759  MOTO-OBJETO FIJO    MOTO  OBJETO FIJO

# %% [markdown]
# Se guarda la base de datos trabajada.

# %%
# Se decide guardar la base de datos trabajada.
hechos.to_csv("../Data/Corregidos/hechos.csv",index=False,sep=";")

# %%
# Se revisa que la base cargue adecuadamente.
hechos = pd.read_csv("../Data/Corregidos/hechos.csv",sep=";")
hechos.head()
# Out:
#           ID  N_VICTIMAS       fecha_completa       FECHA  AAAA  MM  DD  \
# 0  2016-0001           1  2016-01-01 04:00:00  2016-01-01  2016   1   1
# 1  2016-0002           1  2016-01-02 01:15:00  2016-01-02  2016   1   2
# 2  2016-0003           1  2016-01-03 07:00:00  2016-01-03  2016   1   3
# 3  2016-0005           1  2016-12-01 05:20:00  2016-01-21  2016   1  21
# 4  2016-0008           1  2016-12-04 18:30:00  2016-01-24  2016   1  24
#
#        HORA TIPO_DE_CALLE                                Cruce      cruce_r  \
# 0  04:00:00       AVENIDA  FERNANDEZ DE LA CRUZ, F., GRAL. AV.     Es cruce
# 1  01:15:00      GRAL PAZ                  DE LOS CORRALES AV.     Es cruce
# 2  07:00:00       AVENIDA                                  NaN  No es cruce
# 3  05:20:00       AVENIDA              SAENZ PE?A, LUIS, PRES.     Es cruce
# 4  18:30:00       AVENIDA                         ESCALADA AV.     Es cruce
#
#                                Dirección Normalizada  COMUNA   longitud  \
# 0  PIEDRA BUENA AV. y FERNANDEZ DE LA CRUZ, F., G...       8 -58.475340
# 1               PAZ, GRAL. AV. y DE LOS CORRALES AV.       9 -58.508775
# 2                                ENTRE RIOS AV. 2034       1 -58.390403
# 3            SAN JUAN AV. y SAENZ PEÃ‘A, LUIS, PRES.       1 -58.387183
# 4                   27 DE FEBRERO AV. y ESCALADA AV.       8 -58.444513
#
#      latitud     PARTICIPANTES VICTIMA      ACUSADO
# 0 -34.687570         MOTO-AUTO    MOTO         AUTO
# 1 -34.669777    AUTO-PASAJEROS    AUTO    PASAJEROS
# 2 -34.631894         MOTO-AUTO    MOTO         AUTO
# 3 -34.622466    MOTO-PASAJEROS    MOTO    PASAJEROS
# 4 -34.684759  MOTO-OBJETO FIJO    MOTO  OBJETO FIJO

# %% [markdown]
# ### Revisión estadística

# %% [markdown]
# Se decide revisar la existencia de outliers para la base de datos a partir del número de víctimas.

# %%
# Se calcula el Q1 (Primer cuartil) y Q3 (Tercer cuartil).
Q1 = hechos["N_VICTIMAS"].quantile(0.25)
Q3 = hechos["N_VICTIMAS"].quantile(0.75)

print(f"El primer cuartil es {Q1}")
print(f"El tercer cuartil es {Q3}")

# Se hace el cálculo del IQR (Rango Intercuartil).
IQR = Q3 - Q1
print(f"El rango intercuartil es {IQR}")

# Se establecen los límites para encontrar a los outliers.
inferior = Q1 - 1.5 * IQR
superior = Q3 + 1.5 * IQR

# Filtrado de outliers
outliers = hechos[
    (hechos["N_VICTIMAS"] < inferior) | (hechos["N_VICTIMAS"] > superior)
]

# Se observan los casos de outliers
print("Los outliers identificados son:")
outliers
# Out:
# El primer cuartil es 1.0
# El tercer cuartil es 1.0
# El rango intercuartil es 0.0
# Los outliers identificados son:
#             ID  N_VICTIMAS       fecha_completa       FECHA  AAAA  MM  DD  \
# 28   2016-0041           2  2016-03-29 11:00:00  2016-03-29  2016   3  29
# 88   2016-0126           2  2016-09-18 22:45:00  2016-09-18  2016   9  18
# 145  2017-0026           2  2017-02-26 05:15:00  2017-02-26  2017   2  26
# 153  2017-0035           3  2017-03-23 05:00:00  2017-03-23  2017   3  23
# 154  2017-0036           2  2017-03-29 18:00:00  2017-03-29  2017   3  29
# 206  2017-0108           2  2017-09-02 04:53:08  2017-09-02  2017   9   2
# 210  2017-0112           2  2017-09-10 09:32:17  2017-09-10  2017   9  10
# 220  2017-0126           2  2017-10-14 06:15:00  2017-10-14  2017  10  14
# 242  2017-0153           2  2017-12-11 02:00:00  2017-12-11  2017  12  11
# 263  2018-0015           2  2018-02-06 01:00:00  2018-02-06  2018   2   6
# 274  2018-0026           2  2018-03-09 04:45:00  2018-03-09  2018   3   9
# 286  2018-0038           2  2018-04-20 17:10:00  2018-04-20  2018   4  20
# 332  2018-0085           2  2018-08-03 18:16:00  2018-08-03  2018   8   3
# 345  2018-0098           2  2018-09-09 05:00:00  2018-09-09  2018   9   9
# 373  2018-0128           2  2018-11-25 04:30:00  2018-11-25  2018  11  25
# 398  2019-0010           2  2019-02-02 07:50:00  2019-02-02  2019   2   2
# 524  2020-0038           2  2020-08-30 04:00:00  2020-08-30  2020   8  30
# 548  2020-0063           2  2020-12-05 07:10:00  2020-12-05  2020  12   5
# 561  2020-0077           2  2020-12-25 06:40:00  2020-12-25  2020  12  25
#
#          HORA TIPO_DE_CALLE               Cruce      cruce_r  \
# 28   11:00:00       AVENIDA  RIVERA INDARTE AV.     Es cruce
# 88   22:45:00         CALLE           TINOGASTA     Es cruce
# 145  05:15:00       AVENIDA            FOURNIER     Es cruce
# 153  05:00:00       AVENIDA  VILLAFLOR, AZUCENA     Es cruce
# 154  18:00:00      GRAL PAZ             CAMPANA     Es cruce
# 206  04:53:08      GRAL PAZ             MACHAIN     Es cruce
# 210  09:32:17     AUTOPISTA                 NaN  No es cruce
# 220  06:15:00       AVENIDA     CA?ADA DE GOMEZ     Es cruce
# 242  02:00:00       AVENIDA        LA PLATA AV.     Es cruce
# 263  01:00:00       AVENIDA                 NaN  No es cruce
# 274  04:45:00       AVENIDA           SAENZ AV.     Es cruce
# 286  17:10:00       AVENIDA                 NaN  No es cruce
# 332  18:16:00       AVENIDA  GARAY, JUAN DE AV.     Es cruce
# 345  05:00:00      GRAL PAZ    BERON DE ASTRADA     Es cruce
# 373  04:30:00      GRAL PAZ                 NaN  No es cruce
# 398  07:50:00       AVENIDA                 NaN  No es cruce
# 524  04:00:00       AVENIDA     DIAZ, CNEL. AV.     Es cruce
# 548  07:10:00         CALLE         ALTA GRACIA     Es cruce
# 561  06:40:00       AVENIDA        PUNTA ARENAS     Es cruce
#
#                                  Dirección Normalizada  COMUNA   longitud  \
# 28                 DIRECTORIO AV. y RIVERA INDARTE AV.       7 -58.460766
# 88                                IRIGOYEN y TINOGASTA      10 -58.525721
# 145                      MORENO, PERITO AV. y FOURNIER       4 -58.418428
# 153  ACHAVAL RODRIGUEZ, T., DR. AV. y VILLAFLOR, AZ...       1 -58.358815
# 154                           PAZ, GRAL. AV. y CAMPANA      12 -58.514523
# 206                           PAZ, GRAL. AV. y MACHAIN      12 -58.494911
# 210                  AUTOPISTA 25 DE MAYO y VARELA AV.       7 -58.458074
# 220                     RIESTRA AV. y CAÃ‘ADA DE GOMEZ       8 -58.480037
# 242                             ROSARIO y LA PLATA AV.       6 -58.428553
# 263                                 AUSTRALIA AV. 2800       4 -58.386363
# 274     RABANAL, FRANCISCO, INTENDENTE AV. y SAENZ AV.       4 -58.416578
# 286                                 RIVADAVIA AV. 1571       1 -58.388722
# 332                ENTRE RIOS AV. y GARAY, JUAN DE AV.       3 -58.391189
# 345                  PAZ, GRAL. AV. y BERON DE ASTRADA       8 -58.471994
# 373                               PAZ, GRAL. AV. 11200       9 -58.528446
# 398                            DEL LIBERTADOR AV. 4100      14 -58.426685
# 524            LAS HERAS GENERAL AV. y DIAZ, CNEL. AV.      14 -58.406175
# 548                           NUEVA YORK y ALTA GRACIA      11 -58.527838
# 561                      SAN MARTIN AV. y PUNTA ARENAS      15 -58.472209
#
#        latitud     PARTICIPANTES      VICTIMA      ACUSADO
# 28  -34.633504       MOTO-CARGAS         MOTO       CARGAS
# 88  -34.621259       AUTO-CARGAS         AUTO       CARGAS
# 145 -34.649791  AUTO-OBJETO FIJO         AUTO  OBJETO FIJO
# 153 -34.611136  AUTO-OBJETO FIJO         AUTO  OBJETO FIJO
# 154 -34.581598    MOTO-PASAJEROS         MOTO    PASAJEROS
# 206 -34.547956  AUTO-OBJETO FIJO  OBJETO FIJO         AUTO
# 210 -34.639974  AUTO-OBJETO FIJO         AUTO  OBJETO FIJO
# 220 -34.681485  AUTO-OBJETO FIJO         AUTO  OBJETO FIJO
# 242 -34.618294    MOTO-PASAJEROS         MOTO    PASAJEROS
# 263 -34.646843    MOTO-PASAJEROS         MOTO    PASAJEROS
# 274 -34.654762      MOVIL-CARGAS        MOVIL       CARGAS
# 286 -34.608850       PEATON-AUTO       PEATON         AUTO
# 332 -34.627043    MOTO-PASAJEROS         MOTO    PASAJEROS
# 345 -34.696402         AUTO-AUTO         AUTO         AUTO
# 373 -34.645929    AUTO-PASAJEROS         AUTO    PASAJEROS
# 398 -34.569615       PEATON-AUTO       PEATON         AUTO
# 524 -34.583459         AUTO-AUTO         AUTO         AUTO
# 548 -34.610470  PEATON_MOTO-MOTO  PEATON_MOTO         MOTO
# 561 -34.601114         MOTO-AUTO         MOTO         AUTO

# %% [markdown]
# Para esta ocasión, si bien se encuentran casos de outliers por encima del límite superior, son datos que tienen sentido que ocurran (pueden haber accidentes de más de una (1) persona) y no resultan casos muy extremos en comparación (por ejemplo, más de 10 víctimas). Con esto en mente, se decide observar la composición de los datos para N_Víctimas, año (AAAA), Comuna, Victima, y Acusado.

# %%
# Para número de víctimas.
print("Para el número de víctimas:")
print(hechos["N_VICTIMAS"].value_counts(normalize=True))

# Para el año.
print("Para el año:")
print(hechos["AAAA"].value_counts(normalize=True))
# Out:
# Para el número de víctimas:
# N_VICTIMAS
# 1    0.971168
# 2    0.027314
# 3    0.001517
# Name: proportion, dtype: float64
# Para el año:
# AAAA
# 2018    0.212443
# 2016    0.195751
# 2017    0.182094
# 2019    0.150228
# 2021    0.144158
# 2020    0.115326
# Name: proportion, dtype: float64

# %%
# Para la comuna.
print("Para la comuna:")
print(hechos["COMUNA"].value_counts(normalize=True))
# Out:
# Para la comuna:
# COMUNA
# 1     0.133536
# 4     0.109256
# 9     0.095599
# 8     0.092564
# 7     0.084977
# 3     0.068285
# 15    0.066768
# 13    0.056146
# 12    0.051593
# 11    0.047041
# 14    0.047041
# 10    0.044006
# 2     0.037936
# 5     0.033384
# 6     0.031866
# Name: proportion, dtype: float64

# %%
# Para el tipo de víctima. 
print("Para el tipo de víctima:")
print(hechos["VICTIMA"].value_counts(normalize=True))

# Para el tipo de acusado.
print("Para el tipo de acusado:")
print(hechos["ACUSADO"].value_counts(normalize=True))
# Out:
# Para el tipo de víctima:
# VICTIMA
# MOTO           0.423369
# PEATON         0.391502
# AUTO           0.118361
# BICICLETA      0.044006
# CARGAS         0.010622
# PASAJEROS      0.006070
# MOVIL          0.003035
# OBJETO FIJO    0.001517
# PEATON_MOTO    0.001517
# Name: proportion, dtype: float64
# Para el tipo de acusado:
# ACUSADO
# AUTO           0.303490
# PASAJEROS      0.261002
# CARGAS         0.212443
# OBJETO FIJO    0.092564
# MOTO           0.083460
# MULTIPLE       0.025797
# BICICLETA      0.010622
# OTRO           0.009105
# TREN           0.001517
# Name: proportion, dtype: float64

# %% [markdown]
# A partir de las estadísticas que se obtienen, se pueden observar lo siguiente:
#
# - Para el **número de víctima por accidente**, la mayor parte de los accidentes tienen una sóla víctima (aproximadamente el 97%).
#
# - Es importante notar que **la mayoría de los accidentes ocurren en el 2018, 2016 y 2017**. Puede ser importante revisar cambios en las políticas o leyes de tránsito, o si ocurrieron eventos políticos/sociales que hayan podido disminuido la movilización en la región. Es necesario también tener en cuenta que si bien para el año 2020 y 2021 se presenta el menor porcentaje de hechos, estos también se ven permeados por los efectos de la pandemia por COVID-19, lo que puede estar generando cambios en los datos que no se correspondería a otros periodos de tiempo "normales".
#
# - **Para comuna**, se observa que la comuna 1, 4 y 9 son las 3 comunas que presentan más número de accidentes. Puede ser importante revisar la manera en la que los flujos automovilísticos ocurren actualmente para cada una de estas tres comunas, lo que podría favorecer menos tráfico (y menos accidentes) en caso de que sean zonas altamente pobladas o zonas altamente transitadas. Así mismo, puede ser importante que se revisen las razones por las que tantas personas transitan estas comunas (es decir, ¿las personas viven en estas zonas? ¿Transitan por estas zonas por negocios, por motivos de creación, salud, otros?, ¿o tienen que transitar por estas zonas debido a la facilidad de desplazamiento a través de la ciudad por falta de otras vías de acceso?). A partir de la revisión de estas razones, pueden resultar análisis que permitan mejorar la circulación por la ciudad.
#
# - Por el **tipo de víctima**, se observan que las mayores víctimas son motos y peatones por la calle con una elevada diferencia (juntos representan aproximadamente el 80,8% de los hechos registrados) respecto a los demás tipos de víctimas. Puede ser importante tener en cuenta especialmente a estas dos poblaciones al momento de pensar políticas que permitan la protección de las víctimas.
#
# - Para el **tipo de acusado**, se observa que las tres poblaciones que más generan accidentes son conductores de auto, seguido por los pasajeros de vehículos y finalmente a vehículos de carga. Donde estas tres poblaciones representan el 75,9% de los hechos registrados. Puede ser importante indagar más sobre el contexto en estas tres poblaciones respecto al factor humano (por ejemplo, nivel de alcoholemia, distracciones, maniobras imprudentes, falta de sueño o sonambulismo al volante, entre otras) y causas técnicas que pueden ser evitadas (revisión de frenos, carreteras en mal estado, cambio de aceite, presión de los neumáticos, etc.). A partir de estas razones, se pueden generar leyes que puedan prevenir estos casos a partir de obligaciones respecto a la revisión técnica preventiva, y/o de enseñanza de una mejor y más segura cultura al volante.

# %% [markdown]
# Veamos a continuación más relaciones:

# %%
# Relación por número de hechos y año en el que ocurren.

sns.histplot(hechos,x = "AAAA")
plt.xlabel("Año")
plt.ylabel("Total de hechos")
plt.title("Número de hechos por año")
plt.show()

# %% [markdown]
# Como se demostró anteriormente, los años donde más ocurrieron hechos fueron en el 2016 y 2019. Siendo 2020 y 2021 los años con menor número de hechos registrados, en donde es importante tener en cuenta que estos dos años se vieron mayormente afectados por las pandemia de COVID-19. El año 2019 puede ser un periodo importante de revisión ya que se presenta una tendencia a la baja respecto a los tres periodos anteriores (2016 - 2018).

# %%
# Por tipo de calle.
sns.histplot(hechos, x = "TIPO_DE_CALLE",stat="percent")
plt.xlabel("Tipo de Calle")
plt.ylabel("% de Hechos")
plt.title("Hechos por Tipo de Calle")
plt.show()

# %% [markdown]
# En este gráfico observamos el porcentaje de hechos ocurridos por el tipo de calle. Para la data dada, la mayoría de los hechos ocurren en las avenidas (aproximadamente el 60%), seguida de las calles (aprox. 20%). Podría ser importante revisar en qué segmento de estas ocurren los hechos; es decir, si ocurren al momento en el que se produce un intercambio entre una avenida / calle con otra (cruces), o si ocurren durante el recorrido / tránsito de estas.

# %%
# A partir de la pregunta anterior, se desea revisar el número de hechos que ocurren en cruces. Para ello se revisa el total de hechos registrados por tipo de calle y el total de hechos registrados que ocurren en cruces. 

conteo_cruces = hechos.groupby("TIPO_DE_CALLE")[["ID","Cruce"]].count().reset_index() # Se obtiene el número de hechos por tipo de calle, y el número de hechos que ocurren en cruces.
conteo_cruces["%_Representación"] = round((conteo_cruces["Cruce"]/conteo_cruces["ID"])*100,2) # Se obtiene el porcentaje de representación del Cruce para el total de hechos registrados para el tipo de calle en el que ocurre.

# Se observa la tabla resultado.
conteo_cruces
# Out:
#   TIPO_DE_CALLE   ID  Cruce  %_Representación
# 0     AUTOPISTA   55     26             47.27
# 1       AVENIDA  418    343             82.06
# 2         CALLE  129     87             67.44
# 3      GRAL PAZ   57     49             85.96

# %% [markdown]
# Para los cruces, se puede observar que tanto para avenidas, calles y General Paz, los hechos que ocurren en cruces representan la mayor parte de la muestra para cada una de estos tipos de calles. Esto nos puede dar una indicación de la importancia que puede ser el revisar correcta señalización, así como el tráfico en los cruces en donde ocurren estos accidentes (tomando en cuenta las comunas principales revisadas anteriormente). Si bien, en las autopistas los accidentes que ocurren en cruces son menores (debido al tipo de flujo que existen en este tipo de calle), siguen presentándose un importante número de este tipo de hecho.

# %%
# Se observa a continuación las incidencias existentes por tipo de víctima y tipo de acusado.

sns.scatterplot(hechos,x="VICTIMA",y="ACUSADO")
plt.tick_params(axis="x",rotation=45)
plt.xlabel("Tipo de victima")
plt.ylabel("Tipo de acusado")
plt.title("Hechos por acusado y tipo de víctima")
plt.show()

# %% [markdown]
# La gráfica anterior nos permite observar el acontecimiento de hechos de acuerdo al tipo de acusado y al tipo de víctima. Como era de esperar, de acuerdo a los resultados anteriores respecto al número de hechos por tipo de acusado y tipo de víctima, los acusados por auto, pasajeros y carga presentan diversos tipos de víctimas. Como curiosidad de la muestra, sólo se presentan accidentes donde la víctima fue un móvil por razón de los pasajeros y vehículos de carga; así como sólo se registran víctimas de accidente por tren a bicicletas.

# %% [markdown]
# ## Homicidios - Víctimas

# %% [markdown]
# ### Revisión de la base de datos.

# %%
# Se convierte la base de datos en un dataframe de pandas y se observa la composición de las primeras líneas de la base de datos.
victimas = pd.read_excel(ruta_homicidios, sheet_name= "VICTIMAS")
victimas.head()
# Out:
#     ID_hecho      FECHA  AAAA  MM  DD        ROL VICTIMA       SEXO EDAD  \
# 0  2016-0001 2016-01-01  2016   1   1  CONDUCTOR    MOTO  MASCULINO   19
# 1  2016-0002 2016-01-02  2016   1   2  CONDUCTOR    AUTO  MASCULINO   70
# 2  2016-0003 2016-01-03  2016   1   3  CONDUCTOR    MOTO  MASCULINO   30
# 3  2016-0004 2016-01-10  2016   1  10  CONDUCTOR    MOTO  MASCULINO   18
# 4  2016-0005 2016-01-21  2016   1  21  CONDUCTOR    MOTO  MASCULINO   29
#
#    FECHA_FALLECIMIENTO
# 0  2016-01-01 00:00:00
# 1  2016-01-02 00:00:00
# 2  2016-01-03 00:00:00
# 3                   SD
# 4  2016-02-01 00:00:00

# %%
# Se eliminan del dataframe todos aquellos ID que no se encuentren en hechos.
victimas = victimas[victimas["ID_hecho"].isin(hechos["ID"])]

# %%
# Se observa la composición del dataframe.
victimas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 679 entries, 0 to 716
# Data columns (total 10 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ID_hecho             679 non-null    object
#  1   FECHA                679 non-null    datetime64[ns]
#  2   AAAA                 679 non-null    int64
#  3   MM                   679 non-null    int64
#  4   DD                   679 non-null    int64
#  5   ROL                  679 non-null    object
#  6   VICTIMA              679 non-null    object
#  7   SEXO                 679 non-null    object
#  8   EDAD                 679 non-null    object
#  9   FECHA_FALLECIMIENTO  679 non-null    object
# dtypes: datetime64[ns](1), int64(3), object(6)
# memory usage: 58.4+ KB

# %%
# Se observa que la infomración correspondiente a FECHA_FALLECIMIENTO se encuentre en el formato adecuado.
print(f"El tipo de dato de la columna 'FECHA_FALLECIMIENTO' es: {type(victimas.loc[1,"FECHA_FALLECIMIENTO"])}")

# El dato que retorna es el esperado para un dato de tiempo.
# Out:
# El tipo de dato de la columna 'FECHA_FALLECIMIENTO' es: <class 'datetime.datetime'>

# %% [markdown]
# En este caso, el análisis de la información que nos arroja la base nos muestra que no se presentan datos nulos, sin embargo, se decide revisar que no se presenten datos en blanco (" ", "" o ".") para rol, víctima, sexo ni edad.

# %%
# Se filtran las bases de datos para revisar si se presentan cualquiera de los casos mencionados.

print("Para la columna 'victima':")
print(victimas[(victimas["VICTIMA"] == "") | (victimas["VICTIMA"] == " ") | (victimas["VICTIMA"] == ".")])


print("Para la columna 'rol':")
print(victimas[(victimas["ROL"] == "") | (victimas["ROL"] == " ") | (victimas["ROL"] == ".")])


print("Para la columna 'sexo':")
print(victimas[(victimas["SEXO"] == "") | (victimas["SEXO"] == " ") | (victimas["SEXO"] == ".")])


print("Para la columna 'edad':")
print(victimas[(victimas["EDAD"] == "") | (victimas["EDAD"] == " ") | (victimas["EDAD"] == ".")])

# En este caso, se comprueban que no existen datos nulos "válidos" por encontrarse en formato string.
# Out:
# Para la columna 'victima':
# Empty DataFrame
# Columns: [ID_hecho, FECHA, AAAA, MM, DD, ROL, VICTIMA, SEXO, EDAD, FECHA_FALLECIMIENTO]
# Index: []
# Para la columna 'rol':
# Empty DataFrame
# Columns: [ID_hecho, FECHA, AAAA, MM, DD, ROL, VICTIMA, SEXO, EDAD, FECHA_FALLECIMIENTO]
# Index: []
# Para la columna 'sexo':
# Empty DataFrame
# Columns: [ID_hecho, FECHA, AAAA, MM, DD, ROL, VICTIMA, SEXO, EDAD, FECHA_FALLECIMIENTO]
# Index: []
# Para la columna 'edad':
# Empty DataFrame
# Columns: [ID_hecho, FECHA, AAAA, MM, DD, ROL, VICTIMA, SEXO, EDAD, FECHA_FALLECIMIENTO]
# Index: []

# %%
# Se observa que los datos en la columna "EDAD" se encuentran en formato string. Se deciden transformar a tipo entero para poder hacer revisión estadística de esta información posteriormente. Debido a que dentro de la columna de "victimas" existen datos como "SD" (sin identificar), se deciden convertir estos datos a nulo:

victimas["EDAD"] = pd.to_numeric(victimas["EDAD"],errors="coerce",downcast="integer")

# %%
# Se reemplazan todas las coincidencias para "SD" por datos nulos.
victimas.replace("SD",np.nan,inplace=True)

# %%
# Se observa la información obtenida. 
victimas.info()

# Donde se entiende que los datos nulos para edad son aquellos que no se pudieron identificar.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 679 entries, 0 to 716
# Data columns (total 10 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ID_hecho             679 non-null    object
#  1   FECHA                679 non-null    datetime64[ns]
#  2   AAAA                 679 non-null    int64
#  3   MM                   679 non-null    int64
#  4   DD                   679 non-null    int64
#  5   ROL                  677 non-null    object
#  6   VICTIMA              679 non-null    object
#  7   SEXO                 678 non-null    object
#  8   EDAD                 636 non-null    float64
#  9   FECHA_FALLECIMIENTO  627 non-null    object
# dtypes: datetime64[ns](1), float64(1), int64(3), object(5)
# memory usage: 74.5+ KB

# %%
# Se observa un análisis para el dataframe obtenido.
victimas.describe()
# Out:
#                                FECHA         AAAA          MM          DD  \
# count                            679   679.000000  679.000000  679.000000
# mean   2018-09-27 14:27:23.593519872  2018.225331    6.683358   16.041237
# min              2016-01-01 00:00:00  2016.000000    1.000000    1.000000
# 25%              2017-05-06 00:00:00  2017.000000    3.000000    9.000000
# 50%              2018-07-23 00:00:00  2018.000000    7.000000   16.000000
# 75%              2020-01-14 00:00:00  2020.000000   10.000000   23.000000
# max              2021-12-30 00:00:00  2021.000000   12.000000   31.000000
# std                              NaN     1.668962    3.585640    8.677170
#
#              EDAD
# count  636.000000
# mean    42.320755
# min      1.000000
# 25%     27.000000
# 50%     37.000000
# 75%     56.250000
# max     95.000000
# std     19.875382

# %%
# Se guarda la base de datos obtenida.
victimas.to_csv("../Data/Corregidos/victimas.csv",index=False,sep=";")

# %%
# Se observa que la base cargue adecuadamente. 
victimas = pd.read_csv("../Data/Corregidos/victimas.csv",sep=";")
victimas.head()
# Out:
#     ID_hecho       FECHA  AAAA  MM  DD        ROL VICTIMA       SEXO  EDAD  \
# 0  2016-0001  2016-01-01  2016   1   1  CONDUCTOR    MOTO  MASCULINO  19.0
# 1  2016-0002  2016-01-02  2016   1   2  CONDUCTOR    AUTO  MASCULINO  70.0
# 2  2016-0003  2016-01-03  2016   1   3  CONDUCTOR    MOTO  MASCULINO  30.0
# 3  2016-0005  2016-01-21  2016   1  21  CONDUCTOR    MOTO  MASCULINO  29.0
# 4  2016-0008  2016-01-24  2016   1  24  CONDUCTOR    MOTO  MASCULINO  30.0
#
#    FECHA_FALLECIMIENTO
# 0  2016-01-01 00:00:00
# 1  2016-01-02 00:00:00
# 2  2016-01-03 00:00:00
# 3  2016-02-01 00:00:00
# 4  2016-01-24 00:00:00

# %% [markdown]
# ### Revisión estadística.

# %% [markdown]
# Se revisa la presencia de outliers para la base de datos a partir de la edad de las víctimas.

# %%
# Se calcula el Q1 (Primer cuartil) y Q3 (Tercer cuartil).
Q1 = victimas["EDAD"].quantile(0.25)
Q3 = victimas["EDAD"].quantile(0.75)

print(f"El primer cuartil es {Q1}")
print(f"El tercer cuartil es {Q3}")

# Se hace el cálculo del IQR (Rango Intercuartil).
IQR = Q3 - Q1
print(f"El rango intercuartil es {IQR}")

# Se establecen los límites para encontrar a los outliers.
inferior = Q1 - 1.5 * IQR
superior = Q3 + 1.5 * IQR

# Filtrado de outliers
outliers = victimas[
    (victimas["EDAD"] < inferior) | (victimas["EDAD"] > superior)
]

# Se observan los casos de outliers
print("Los outliers identificados son:")
outliers

# En este caso, no se identifican outliers para la edad de las personas.
# Out:
# El primer cuartil es 27.0
# El tercer cuartil es 56.25
# El rango intercuartil es 29.25
# Los outliers identificados son:
# Empty DataFrame
# Columns: [ID_hecho, FECHA, AAAA, MM, DD, ROL, VICTIMA, SEXO, EDAD, FECHA_FALLECIMIENTO]
# Index: []

# %% [markdown]
# Observemos a continuación la composición del dataframe. En este caso, veremos primero la distribución de los datos para la columna rol, víctima y sexo.

# %%
# Se imprime la distribución de los valores para estas tres columnas.

# ROL:
print(victimas["ROL"].value_counts(normalize=True))

# Se grafica el número de incidencias.
sns.histplot(victimas,x = "ROL")
plt.tick_params(axis="x",rotation=45)
plt.title("Número de incidentes por tipo de Rol de la Víctima")
plt.ylabel("Conteo")
plt.xlabel("Tipo de rol")
plt.show()
# Out:
# ROL
# CONDUCTOR               0.459380
# PEATON                  0.385524
# PASAJERO_ACOMPAÑANTE    0.112260
# CICLISTA                0.042836
# Name: proportion, dtype: float64

# %%
# VICTIMA:
print(victimas["VICTIMA"].value_counts(normalize=True))

# Se grafica el número de incidencias.
sns.histplot(victimas,x = "VICTIMA")
plt.tick_params(axis="x",rotation=45)
plt.title("Número de incidentes por tipo de Víctima")
plt.ylabel("Conteo")
plt.xlabel("Tipo de Víctima")
plt.show()
# Out:
# VICTIMA
# MOTO         0.421208
# PEATON       0.384389
# AUTO         0.131075
# BICICLETA    0.042710
# CARGAS       0.010309
# PASAJEROS    0.005891
# MOVIL        0.004418
# Name: proportion, dtype: float64

# %%
# SEXO:
print(victimas["SEXO"].value_counts(normalize=True))

# Se grafica el número de incidencias.
sns.histplot(victimas,x = "SEXO")
plt.title("Número de incidentes por sexo de la Víctima")
plt.ylabel("Conteo")
plt.xlabel("Sexo")
plt.show()
# Out:
# SEXO
# MASCULINO    0.758112
# FEMENINO     0.241888
# Name: proportion, dtype: float64

# %% [markdown]
# En este caso, los resultados nos permiten observar lo siguiente:
#
# - Para el caso por tipo de rol, se observan que la mayor parte de las víctimas eran conductores (46%), esto resulta coherente con el dato del tipo de vehículo víctima de los accidentes (moto). La información aquí presente resulta coherente con los resultados de la base "hechos", por tipo de víctima.
#
# - Los incidentes por tipo de víctima resulta también coherente con la información presentada en la base de "hechos", donde la mayor incidencia de víctimas son motos, peatones y autos. Un hallazgo interesante de la muestra nos permite observar que las bicicletas, si bien son el 4to grupo de víctimas con más hechos, tiene un menor número de incidencias que los otros tres grupos. Esto nos podría invitar a revisar si el número de ciclistas en la calle es mucho menor que los otros tres grupos. En caso de que la diferencia de ciclistas no sea extremadamente elevada respecto a los primeros tres grupos, revisar más a detalle las rutas de los ciclistas y las diferencias que se presentan con peatones respecto, podría resultar de apoyo para pensar estrategias que reduzcan los hechos en este segundo grupo.
#
# - Finalmente, la mayoría de las víctimas son de sexo masculino (76% de los datos). Podría ser útil, en una segunda instancia, revisar si el número de conductores con pase, o el promedio de conductores diario, presenta una diferencia igual de significativa, ya que de presentarse una menor diferencia entre el número general de conductores por sexo, esto nos invitaría a revisar con más detalle los hábitos al volante y en la calle entre los dos sexos que puedan hacer propensos los accidentes. La muestra en sí misma, no obstante, nos invitaría a revisar estos mismos hábitos.

# %% [markdown]
# ## Lesiones - Hechos

# %% [markdown]
# ### Revisión de la base

# %%
# Se extrae la hoja 
lesiones = pd.read_excel(ruta_lesiones,sheet_name="HECHOS")
lesiones.head()
# Out:
#                 id  n_victimas  aaaa  mm  dd                fecha      hora  \
# 0  LC-2019-0000179           1  2019   1   1  2019-01-01 00:00:00  09:00:00
# 1  LC-2019-0000053           1  2019   1   1  2019-01-01 00:00:00  01:55:00
# 2  LC-2019-0000063           1  2019   1   1  2019-01-01 00:00:00  02:00:00
# 3  LC-2019-0000079           1  2019   1   1  2019-01-01 00:00:00  02:30:00
# 4  LC-2019-0000082           4  2019   1   1  2019-01-01 00:00:00  04:30:00
#
#   franja_hora direccion_normalizada comuna  ...     latutid   victima acusado  \
# 0           9                    SD     14  ...  -34.559658  CICLISTA      SD
# 1           1                    SD      8  ...  -34.669125      AUTO      SD
# 2           2                    SD      8  ...  -34.677556        SD      SD
# 3           2                    SD      7  ...  -34.647349    PEATON      SD
# 4           4                    SD      3  ...  -34.604579      AUTO      SD
#
#    participantes moto auto transporte_publico camion ciclista gravedad
# 0    CICLISTA-SD   SD   SD                 SD     SD        x       SD
# 1        AUTO-SD   SD    x                 SD     SD       SD       SD
# 2          SD-SD   SD   SD                 SD     SD       SD       SD
# 3      PEATON-SD    x   SD                 SD     SD       SD       SD
# 4        AUTO-SD   SD   SD                  x     SD       SD       SD
#
# [5 rows x 27 columns]

# %%
# Se revisa el contenido de la hoja.
print(lesiones.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23785 entries, 0 to 23784
# Data columns (total 27 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     23785 non-null  object
#  1   n_victimas             23785 non-null  int64
#  2   aaaa                   23785 non-null  int64
#  3   mm                     23785 non-null  int64
#  4   dd                     23785 non-null  int64
#  5   fecha                  23785 non-null  object
#  6   hora                   23785 non-null  object
#  7   franja_hora            23780 non-null  object
#  8   direccion_normalizada  23732 non-null  object
#  9   comuna                 23616 non-null  object
#  10  tipo_calle             23785 non-null  object
#  11  otra_direccion         23785 non-null  object
#  12  calle                  12867 non-null  object
#  13  altura                 12771 non-null  float64
#  14  cruce                  9407 non-null   object
#  15  geocodificacion_CABA   23746 non-null  object
#  16  longitud               23523 non-null  object
#  17  latutid                23523 non-null  object
#  18  victima                23785 non-null  object
#  19  acusado                23785 non-null  object
#  20  participantes          23785 non-null  object
#  21  moto                   23692 non-null  object
#  22  auto                   23692 non-null  object
#  23  transporte_publico     23692 non-null  object
#  24  camion                 23692 non-null  object
#  25  ciclista               23692 non-null  object
#  26  gravedad               23785 non-null  object
# dtypes: float64(1), int64(4), object(22)
# memory usage: 4.9+ MB
# None

# %%
# Se deciden eliminar las siguientes columnas, ya que presentan información que puede obtenerse por la longitud y la latitud: 
lesiones.drop(columns=["direccion_normalizada","otra_direccion","calle","altura","geocodificacion_CABA"],inplace=True)

# %%
# Se observa la base obtenida. 
lesiones.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23785 entries, 0 to 23784
# Data columns (total 22 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   id                  23785 non-null  object
#  1   n_victimas          23785 non-null  int64
#  2   aaaa                23785 non-null  int64
#  3   mm                  23785 non-null  int64
#  4   dd                  23785 non-null  int64
#  5   fecha               23785 non-null  object
#  6   hora                23785 non-null  object
#  7   franja_hora         23780 non-null  object
#  8   comuna              23616 non-null  object
#  9   tipo_calle          23785 non-null  object
#  10  cruce               9407 non-null   object
#  11  longitud            23523 non-null  object
#  12  latutid             23523 non-null  object
#  13  victima             23785 non-null  object
#  14  acusado             23785 non-null  object
#  15  participantes       23785 non-null  object
#  16  moto                23692 non-null  object
#  17  auto                23692 non-null  object
#  18  transporte_publico  23692 non-null  object
#  19  camion              23692 non-null  object
#  20  ciclista            23692 non-null  object
#  21  gravedad            23785 non-null  object
# dtypes: int64(4), object(18)
# memory usage: 4.0+ MB

# %%
# Se observa que los datos en la columna "longitud" y "latutid" se encuentran en formato string. Se deciden transformar a tipo entero para poder hacer revisión estadística de esta información posteriormente. Debido a que dentro de la columna de "victimas" existen datos como "SD" (sin identificar), se deciden convertir estos datos a nulo:

lesiones["longitud"] = pd.to_numeric(lesiones["longitud"],errors="coerce",downcast="float")
lesiones["latutid"] = pd.to_numeric(lesiones["latutid"],errors="coerce",downcast="float")

lesiones.head()
# Out:
#                 id  n_victimas  aaaa  mm  dd                fecha      hora  \
# 0  LC-2019-0000179           1  2019   1   1  2019-01-01 00:00:00  09:00:00
# 1  LC-2019-0000053           1  2019   1   1  2019-01-01 00:00:00  01:55:00
# 2  LC-2019-0000063           1  2019   1   1  2019-01-01 00:00:00  02:00:00
# 3  LC-2019-0000079           1  2019   1   1  2019-01-01 00:00:00  02:30:00
# 4  LC-2019-0000082           4  2019   1   1  2019-01-01 00:00:00  04:30:00
#
#   franja_hora comuna tipo_calle  ...    latutid   victima  acusado  \
# 0           9     14         SD  ... -34.559658  CICLISTA       SD
# 1           1      8         SD  ... -34.669125      AUTO       SD
# 2           2      8         SD  ... -34.677556        SD       SD
# 3           2      7         SD  ... -34.647349    PEATON       SD
# 4           4      3         SD  ... -34.604579      AUTO       SD
#
#   participantes moto auto transporte_publico camion ciclista gravedad
# 0   CICLISTA-SD   SD   SD                 SD     SD        x       SD
# 1       AUTO-SD   SD    x                 SD     SD       SD       SD
# 2         SD-SD   SD   SD                 SD     SD       SD       SD
# 3     PEATON-SD    x   SD                 SD     SD       SD       SD
# 4       AUTO-SD   SD   SD                  x     SD       SD       SD
#
# [5 rows x 22 columns]

# %%
# Se renombra la columna "latutid" a "latitud":
lesiones.rename(columns={"latutid":"latitud"},inplace=True)

# %% [markdown]
# Para entender mejor la composición actual de la base de datos, se decide revisar la composición de las columnas comuna, tipo_calle, victima, acusado y gravedad, y conocer mejor cómo tratar los casos sin identificar.

# %%
# Se observa la composición de la base de datos para: comuna, tipo_calle, victima, acusado y gravedad.

# Comuna
print(lesiones["comuna"].value_counts(normalize=True))
# Out:
# comuna
# 1                  0.106961
# 15                 0.080793
# 4                  0.073213
# 3                  0.072747
# 9                  0.070884
# 14                 0.066946
# 7                  0.064194
# 12                 0.060976
# 11                 0.059748
# 13                 0.057376
# 10                 0.057038
# 5                  0.051914
# 8                  0.044970
# 6                  0.040523
# 2                  0.037178
# SD                 0.035823
# No Especificada    0.018716
# Name: proportion, dtype: float64

# %%
# tipo_calle
print(lesiones["tipo_calle"].value_counts(normalize=True))
# Out:
# tipo_calle
# SD           0.464368
# AVENIDA      0.284843
# CALLE        0.226319
# GRAL PAZ     0.022619
# AUTOPISTA    0.001850
# Name: proportion, dtype: float64

# %%
# victima
print(lesiones["victima"].value_counts(normalize=True))
# Out:
# victima
# SD                    0.451251
# MOTO                  0.229598
# CICLISTA              0.092874
# AUTO                  0.085474
# PEATON                0.085180
# TRANSPORTE PUBLICO    0.028505
# CAMIONETA             0.007946
# TAXI                  0.007652
# MOVIL                 0.004204
# CAMION                0.003321
# MIXTO                 0.001766
# MONOPATIN             0.001177
# OTRO                  0.000547
# UTILITARIO            0.000505
# Name: proportion, dtype: float64

# %%
# acusado
print(lesiones["acusado"].value_counts(normalize=True))
# Out:
# acusado
# SD                    0.642758
# AUTO                  0.195123
# TRANSPORTE PUBLICO    0.040992
# CAMIONETA             0.036662
# MOTO                  0.026277
# TAXI                  0.024848
# CAMION                0.012108
# OBJETO FIJO           0.011730
# MOVIL                 0.003406
# CICLISTA              0.003237
# UTILITARIO            0.001177
# OTRO                  0.001009
# PEATON                0.000547
# MONOPATIN             0.000126
# Name: proportion, dtype: float64

# %%
# gravedad
print(lesiones["gravedad"].value_counts(normalize=True))
# Out:
# gravedad
# SD       0.969350
# GRAVE    0.026992
# sd       0.003490
# FATAL    0.000126
# grave    0.000042
# Name: proportion, dtype: float64

# %% [markdown]
# En todas las columnas se observa una elevada proporción de casos sin identificar. Se procede a eliminar la información para todas las columnas cuya información sea SD.

# %%
# Se reemplaza a "SD" por valores nulos.
lesiones.replace(["SD","sd","No Especificada"],np.nan,inplace=True)

# %%
# La información que encontramos en las columnas "moto","auto","transporte_publico", "camion" y "ciclista" se puede observar en "victima","acusado" y "participantes", por lo que se deciden eliminar por redundancia.

lesiones.drop(columns=["moto","auto","transporte_publico", "camion","ciclista"],inplace=True)

# %%
# Se observa la información obtenida. 
lesiones.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23785 entries, 0 to 23784
# Data columns (total 17 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             23785 non-null  object
#  1   n_victimas     23785 non-null  int64
#  2   aaaa           23785 non-null  int64
#  3   mm             23785 non-null  int64
#  4   dd             23785 non-null  int64
#  5   fecha          23785 non-null  object
#  6   hora           23776 non-null  object
#  7   franja_hora    23776 non-null  float64
#  8   comuna         22328 non-null  float64
#  9   tipo_calle     12740 non-null  object
#  10  cruce          9407 non-null   object
#  11  longitud       22314 non-null  float64
#  12  latitud        22314 non-null  float64
#  13  victima        13052 non-null  object
#  14  acusado        8497 non-null   object
#  15  participantes  23785 non-null  object
#  16  gravedad       646 non-null    object
# dtypes: float64(4), int64(4), object(9)
# memory usage: 3.1+ MB

# %%
# Se deciden eliminar todos los valores de las columnas anteriores se encuentran en nulo, ya que no serán de utilidad para el análisis posterior.
lesiones.dropna(subset=["comuna","tipo_calle","victima","acusado"],how="all",inplace=True)

# %%
# Se deciden eliminar todos los valores donde víctima y acusado sean nulos.
lesiones.dropna(subset=["victima","acusado"],how="all",inplace=True)

# %%
# se observa el resultado de la limpieza.
lesiones.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 13250 entries, 0 to 23784
# Data columns (total 17 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             13250 non-null  object
#  1   n_victimas     13250 non-null  int64
#  2   aaaa           13250 non-null  int64
#  3   mm             13250 non-null  int64
#  4   dd             13250 non-null  int64
#  5   fecha          13250 non-null  object
#  6   hora           13245 non-null  object
#  7   franja_hora    13245 non-null  float64
#  8   comuna         12520 non-null  float64
#  9   tipo_calle     9479 non-null   object
#  10  cruce          7028 non-null   object
#  11  longitud       12538 non-null  float64
#  12  latitud        12538 non-null  float64
#  13  victima        13052 non-null  object
#  14  acusado        8497 non-null   object
#  15  participantes  13250 non-null  object
#  16  gravedad       449 non-null    object
# dtypes: float64(4), int64(4), object(9)
# memory usage: 1.8+ MB

# %%
# Se observa el dataframe.
lesiones
# Out:
#                     id  n_victimas  aaaa  mm  dd                fecha  \
# 0      LC-2019-0000179           1  2019   1   1  2019-01-01 00:00:00
# 1      LC-2019-0000053           1  2019   1   1  2019-01-01 00:00:00
# 3      LC-2019-0000079           1  2019   1   1  2019-01-01 00:00:00
# 4      LC-2019-0000082           4  2019   1   1  2019-01-01 00:00:00
# 5      LC-2019-0000136           2  2019   1   1  2019-01-01 00:00:00
# ...                ...         ...   ...  ..  ..                  ...
# 23746  LC-2021-0650349           1  2021  12  30  2021-12-30 00:00:00
# 23768  LC-2021-0652048           1  2021  12  31  2021-12-31 00:00:00
# 23773  LC-2021-0652316           5  2021  12  31  2021-12-31 00:00:00
# 23783  LC-2021-0652921           1  2021  12  31  2021-12-31 00:00:00
# 23784  LC-2020-0244615           1  2020   5  17            5/17/2020
#
#            hora  franja_hora  comuna tipo_calle               cruce  \
# 0      09:00:00          9.0    14.0        NaN                 NaN
# 1      01:55:00          1.0     8.0        NaN                 NaN
# 3      02:30:00          2.0     7.0        NaN                 NaN
# 4      04:30:00          4.0     3.0        NaN                 NaN
# 5      08:05:00          8.0    15.0        NaN                 NaN
# ...         ...          ...     ...        ...                 ...
# 23746  06:38:00          6.0    15.0      CALLE                 NaN
# 23768  01:45:00          1.0     4.0    AVENIDA  BARROS PAZOS, JOSE
# 23773  09:00:00          9.0    13.0      CALLE    PEDRAZA, MANUELA
# 23783  22:00:00         22.0     5.0      CALLE              MORENO
# 23784  21:00:00         21.0     NaN        NaN                 NaN
#
#            longitud       latitud   victima             acusado  \
# 0     -5.840891e+01 -3.455966e+01  CICLISTA                 NaN
# 1     -5.844351e+01 -3.466913e+01      AUTO                 NaN
# 3     -5.843742e+01 -3.464735e+01    PEATON                 NaN
# 4     -5.839822e+01 -3.460458e+01      AUTO                 NaN
# 5     -5.843939e+01 -3.458811e+01      MOTO                 NaN
# ...             ...           ...       ...                 ...
# 23746 -5.847109e+01 -3.457845e+01      MOTO                AUTO
# 23768 -5.843110e+01 -3.464592e+01      MOTO              CAMION
# 23773 -5.846064e+01 -3.454839e+01      AUTO                 NaN
# 23783 -5.841453e+01 -3.461429e+01      MOTO  TRANSPORTE PUBLICO
# 23784 -5.829963e+09 -3.472891e+09      MOTO                AUTO
#
#                  participantes gravedad
# 0                  CICLISTA-SD      NaN
# 1                      AUTO-SD      NaN
# 3                    PEATON-SD      NaN
# 4                      AUTO-SD      NaN
# 5                      MOTO-SD      NaN
# ...                        ...      ...
# 23746                MOTO-AUTO      NaN
# 23768              MOTO-CAMION      NaN
# 23773                  AUTO-SD      NaN
# 23783  MOTO-TRANSPORTE PUBLICO    GRAVE
# 23784                MOTO-AUTO      NaN
#
# [13250 rows x 17 columns]

# %%
# Se observa el análisis estadístico de los datos obtenidos. 
lesiones.describe()
# Out:
#          n_victimas          aaaa            mm            dd   franja_hora  \
# count  13250.000000  13250.000000  13250.000000  13250.000000  13245.000000
# mean       1.131547   2020.177811      6.287849     15.465736     13.568290
# std        0.491279      0.782048      3.605438      8.773622      5.651269
# min        1.000000   2019.000000      1.000000      1.000000      0.000000
# 25%        1.000000   2020.000000      3.000000      8.000000     10.000000
# 50%        1.000000   2020.000000      6.000000     15.000000     14.000000
# 75%        1.000000   2021.000000      9.000000     23.000000     18.000000
# max       10.000000   2021.000000     12.000000     31.000000     23.000000
#
#              comuna      longitud       latitud
# count  12520.000000  1.253800e+04  1.253800e+04
# mean       8.167891 -4.650419e+05 -2.770238e+05
# std        4.668781  5.206570e+07  3.101537e+07
# min        1.000000 -5.829963e+09 -3.472891e+09
# 25%        4.000000 -5.847721e+01 -3.463209e+01
# 50%        9.000000 -5.844159e+01 -3.461093e+01
# 75%       12.000000 -5.840546e+01 -3.458903e+01
# max       15.000000 -5.835346e+01 -3.453466e+01

# %% [markdown]
# Se observan outliers por número de víctimas.

# %%
# Se calcula el Q1 (Primer cuartil) y Q3 (Tercer cuartil).
Q1 = lesiones["n_victimas"].quantile(0.25)
Q3 = lesiones["n_victimas"].quantile(0.75)

print(f"El primer cuartil es {Q1}")
print(f"El tercer cuartil es {Q3}")

# Se hace el cálculo del IQR (Rango Intercuartil).
IQR = Q3 - Q1
print(f"El rango intercuartil es {IQR}")

# Se establecen los límites para encontrar a los outliers.
inferior = Q1 - 1.5 * IQR
superior = Q3 + 1.5 * IQR

# Filtrado de outliers
outliers = lesiones[
    (lesiones["n_victimas"] < inferior) | (lesiones["n_victimas"] > superior)
]

# Se observan los casos de outliers
print("Los outliers identificados son:")
outliers

# En este caso, no se identifican outliers para la edad de las personas.
# Out:
# El primer cuartil es 1.0
# El tercer cuartil es 1.0
# El rango intercuartil es 0.0
# Los outliers identificados son:
#                     id  n_victimas  aaaa  mm  dd                fecha  \
# 4      LC-2019-0000082           4  2019   1   1  2019-01-01 00:00:00
# 5      LC-2019-0000136           2  2019   1   1  2019-01-01 00:00:00
# 11     LC-2019-0000445           3  2019   1   1  2019-01-01 00:00:00
# 20     LC-2019-0000963           5  2019   1   2  2019-01-02 00:00:00
# 60     LC-2019-0006068           2  2019   1   4  2019-01-04 00:00:00
# ...                ...         ...   ...  ..  ..                  ...
# 23678  LC-2021-0642674           2  2021  12  26  2021-12-26 00:00:00
# 23703  LC-2021-0645171           2  2021  12  27  2021-12-27 00:00:00
# 23713  LC-2021-0646632           3  2021  12  28  2021-12-28 00:00:00
# 23741  LC-2021-0649913           2  2021  12  29  2021-12-29 00:00:00
# 23773  LC-2021-0652316           5  2021  12  31  2021-12-31 00:00:00
#
#            hora  franja_hora  comuna tipo_calle              cruce   longitud  \
# 4      04:30:00          4.0     3.0        NaN                NaN -58.398225
# 5      08:05:00          8.0    15.0        NaN                NaN -58.439392
# 11     13:40:00         13.0    11.0        NaN                NaN -58.524662
# 20     08:30:00          8.0     6.0        NaN                NaN -58.447266
# 60     02:49:00          2.0     3.0        NaN                NaN -58.397630
# ...         ...          ...     ...        ...                ...        ...
# 23678  01:00:00          1.0     9.0      CALLE  SUAREZ, JOSE LEON -58.501270
# 23703  17:00:00         17.0     6.0    AVENIDA               MIRO -58.449112
# 23713  09:00:00          9.0     1.0    AVENIDA   CEVALLOS, VIRREY -58.388654
# 23741  23:05:00         23.0    12.0      CALLE            LUGONES -58.479975
# 23773  09:00:00          9.0    13.0      CALLE   PEDRAZA, MANUELA -58.460642
#
#          latitud             victima    acusado          participantes  \
# 4     -34.604579                AUTO        NaN                AUTO-SD
# 5     -34.588108                MOTO        NaN                MOTO-SD
# 11    -34.603255                AUTO        NaN                AUTO-SD
# 20    -34.622984  TRANSPORTE PUBLICO        NaN  TRANSPORTE PUBLICO-SD
# 60    -34.617325                MOTO        NaN                MOTO-SD
# ...          ...                 ...        ...                    ...
# 23678 -34.672195              PEATON  CAMIONETA       PEATON-CAMIONETA
# 23703 -34.625994                MOTO       AUTO              MOTO-AUTO
# 23713 -34.622559              PEATON       MOTO            PEATON-MOTO
# 23741 -34.570591                MOTO       MOTO              MOTO-MOTO
# 23773 -34.548395                AUTO        NaN                AUTO-SD
#
#       gravedad
# 4          NaN
# 5          NaN
# 11         NaN
# 20         NaN
# 60         NaN
# ...        ...
# 23678      NaN
# 23703      NaN
# 23713      NaN
# 23741      NaN
# 23773      NaN
#
# [1288 rows x 17 columns]

# %%
# Se quiere observar los diferentes números de víctimas que se obtuvieron para los outliers:
outliers["n_victimas"].unique()

# En este caso, hace sentido que existan un número de heridos mayores a uno, tales como 2, 3 y 4. Sin embargo, hay otros datos que se alejan más del límite superior.
# Out:
# array([ 4,  2,  3,  5, 10,  8,  7,  6], dtype=int64)

# %% [markdown]
# Se quieren observan los datos de los outliers que se alejan enormemente de la media (de acuerdo al resultado del describe anterior, la desviación para el número de víctimas es de 0.491279, donde el promedio es 1.131547), en este caso, se entenderán como "enormemente alejados de la media" como aquellos que están por encima de 9 desviaciones estándar del promedio.

# %%
# Se observan los casos de los outliers que se alejan enormemente de la media.

desviacion = lesiones["n_victimas"].std()
promedio = lesiones["n_victimas"].mean()

print(f"La desviación estándar es de {desviacion}")
print(f"La media es de {promedio}")

alejados = (desviacion*9)+promedio

print(f"Los datos enormemente alejados de la media son aquellos mayores a {alejados}, los cuales son:")
outliers[outliers["n_victimas"] > alejados]
# Out:
# La desviación estándar es de 0.4912790113828907
# La media es de 1.1315471698113209
# Los datos enormemente alejados de la media son aquellos mayores a 5.553058272257338, los cuales son:
#                     id  n_victimas  aaaa  mm  dd                fecha  \
# 524    LC-2019-0049800          10  2019   1  23  2019-01-23 00:00:00
# 4138   LC-2019-0315787           8  2019   5  20  2019-05-20 00:00:00
# 4589   LC-2019-0348447           8  2019   6   4  2019-06-04 00:00:00
# 6164   LC-2019-0459476           8  2019   7  25  2019-07-25 00:00:00
# 11634  LC-2020-0087811           7  2020   2  10  2020-02-10 00:00:00
# 11871  LC-2020-0112197           8  2020   2  20  2020-02-20 00:00:00
# 12508  LC-2020-0188608           8  2020   4   4  2020-04-04 00:00:00
# 14821  LC-2020-0590451           7  2020  10  31  2020-10-31 00:00:00
# 15691  LC-2020-0660293           6  2020  12  15  2020-12-15 00:00:00
# 18133  LC-2021-0118684           6  2021   3  15  2021-03-15 00:00:00
# 18162  LC-2021-0121638           6  2021   3  17  2021-03-17 00:00:00
# 18328  LC-2021-0137640          10  2021   3  26  2021-03-26 00:00:00
# 18881  LC-2021-0195449           7  2021   4  28  2021-04-28 00:00:00
# 20316  LC-2021-0376565           6  2021   7  29  2021-07-29 00:00:00
# 20561  LC-2021-0394519           6  2021   8   9  2021-08-09 00:00:00
# 21542  LC-2021-0471532           7  2021   9  22  2021-09-22 00:00:00
# 22339  LC-2021-0533418           8  2021  10  26  2021-10-26 00:00:00
# 22559  LC-2021-0552311           8  2021  11   5  2021-11-05 00:00:00
# 23381  LC-2021-0622993           8  2021  12  15  2021-12-15 00:00:00
# 23466  LC-2021-0628972           8  2021  12  17  2021-12-17 00:00:00
#
#                 hora  franja_hora  comuna tipo_calle  \
# 524         18:30:00         18.0     7.0        NaN
# 4138        23:15:00         23.0     1.0        NaN
# 4589        12:40:00         12.0    10.0        NaN
# 6164        01:00:00          1.0    15.0        NaN
# 11634  04:40:00 p.m.         16.0    15.0    AVENIDA
# 11871  09:50:00 a.m.          9.0     1.0      CALLE
# 12508  08:50:00 a.m.          8.0     9.0   GRAL PAZ
# 14821  05:09:00 a.m.          5.0    15.0      CALLE
# 15691  10:00:00 p.m.         22.0     9.0   GRAL PAZ
# 18133       17:50:00         17.0     1.0      CALLE
# 18162       09:40:00          9.0     4.0    AVENIDA
# 18328       12:40:00         12.0     9.0      CALLE
# 18881       16:10:00         16.0     4.0      CALLE
# 20316       16:35:00         16.0     4.0    AVENIDA
# 20561       20:30:00         20.0     4.0      CALLE
# 21542       15:45:00         15.0    14.0      CALLE
# 22339       16:40:00         16.0     9.0    AVENIDA
# 22559       13:00:00         13.0     5.0    AVENIDA
# 23381       03:20:00          3.0     4.0      CALLE
# 23466       16:00:00         16.0    11.0      CALLE
#
#                                 cruce   longitud    latitud  \
# 524                               NaN -58.443316 -34.642061
# 4138                              NaN -58.389660 -34.625064
# 4589                              NaN -58.525719 -34.621259
# 6164                              NaN -58.448650 -34.592646
# 11634  CARRIL, SALVADOR MARIA DEL AV. -58.498201 -34.590701
# 11871                        SAN JOSE -58.385958 -34.614551
# 12508              CASTRO, EMILIO AV. -58.525766 -34.656887
# 14821                         SERRANO -58.443686 -34.597243
# 15691                  PERON, EVA AV. -58.502518 -34.674503
# 18133                             NaN -58.383180 -34.622756
# 18162                          IGUAZU -58.405047 -34.649796
# 18328                         GUAMINI -58.502096 -34.668862
# 18881               TABORDA, DIOGENES -58.409690 -34.650553
# 20316                             NaN -58.358365 -34.626863
# 20561                     SAN ANTONIO -58.375711 -34.655841
# 21542           LAS HERAS GENERAL AV. -58.416953 -34.581574
# 22339        LASSERRE, AUGUSTO, ALTE. -58.514912 -34.660535
# 22559                     MEDRANO AV. -58.421011 -34.611479
# 23381       MONTES DE OCA, MANUEL AV. -58.374584 -34.638674
# 23466                             NaN -58.462417 -34.610534
#
#                   victima             acusado  \
# 524                  OTRO                 NaN
# 4138   TRANSPORTE PUBLICO                 NaN
# 4589                 AUTO                 NaN
# 6164   TRANSPORTE PUBLICO                 NaN
# 11634  TRANSPORTE PUBLICO  TRANSPORTE PUBLICO
# 11871  TRANSPORTE PUBLICO  TRANSPORTE PUBLICO
# 12508               MIXTO              CAMION
# 14821               MIXTO  TRANSPORTE PUBLICO
# 15691                AUTO                AUTO
# 18133              CAMION  TRANSPORTE PUBLICO
# 18162  TRANSPORTE PUBLICO           CAMIONETA
# 18328  TRANSPORTE PUBLICO           CAMIONETA
# 18881  TRANSPORTE PUBLICO  TRANSPORTE PUBLICO
# 20316  TRANSPORTE PUBLICO  TRANSPORTE PUBLICO
# 20561                AUTO  TRANSPORTE PUBLICO
# 21542  TRANSPORTE PUBLICO  TRANSPORTE PUBLICO
# 22339               MOVIL                AUTO
# 22559  TRANSPORTE PUBLICO                AUTO
# 23381           CAMIONETA  TRANSPORTE PUBLICO
# 23466                AUTO                AUTO
#
#                                participantes gravedad
# 524                                  OTRO-SD      NaN
# 4138                   TRANSPORTE PUBLICO-SD      NaN
# 4589                                 AUTO-SD      NaN
# 6164                   TRANSPORTE PUBLICO-SD      NaN
# 11634  TRANSPORTE PUBLICO-TRANSPORTE PUBLICO      NaN
# 11871  TRANSPORTE PUBLICO-TRANSPORTE PUBLICO      NaN
# 12508                           MIXTO-CAMION      NaN
# 14821               MIXTO-TRANSPORTE PUBLICO      NaN
# 15691                              AUTO-AUTO      NaN
# 18133              CAMION-TRANSPORTE PUBLICO    GRAVE
# 18162           TRANSPORTE PUBLICO-CAMIONETA      NaN
# 18328           TRANSPORTE PUBLICO-CAMIONETA    GRAVE
# 18881  TRANSPORTE PUBLICO-TRANSPORTE PUBLICO      NaN
# 20316  TRANSPORTE PUBLICO-TRANSPORTE PUBLICO      NaN
# 20561                AUTO-TRANSPORTE PUBLICO    GRAVE
# 21542  TRANSPORTE PUBLICO-TRANSPORTE PUBLICO      NaN
# 22339                             MOVIL-AUTO      NaN
# 22559                TRANSPORTE PUBLICO-AUTO      NaN
# 23381           CAMIONETA-TRANSPORTE PUBLICO    GRAVE
# 23466                              AUTO-AUTO      NaN

# %% [markdown]
# En este caso se observa que los outliers encontrados para los datos que se alejan enormente de la media hacen sentido por el tipo de vehículos participante en el accidente. Dos autos pueden causar accidentes de hasta 10 personas si se cuentan sólo los pasajeros de cada vehículo, mientras que en el caso del transporte público también hace sentido que se puedan presentar número elevado de víctimas.
#
# Especialmente llaman la atención la línea 524 (otro - sd), 4589(auto - sd), y 22339 (movil - auto).
#
# Sin embargo, a falta de mayor contexto para entender estos tres datos, se deciden dejar en la muestra.

# %%
# El total de outliers en la muestra respecto a la muestra total es el siguiente:
n_out = outliers["id"].count()
muestra = lesiones["id"].count()

print(f"El total de outliers es de {n_out} lo que representa {round((n_out/muestra),4)*100} % de la muestra total")

# En este caso, los outliers representan el 9.7% de la muestra total de datos, lo que sigue siendo una importante parte de la muestra total. Se deciden dejar los datos obtenidos.
# Out:
# El total de outliers es de 1288 lo que representa 9.719999999999999 % de la muestra total

# %%
# Se corrige en gravedad a "grave" por "GRAVE"
lesiones["gravedad"].replace("grave","GRAVE",inplace=True)

# %%
# Es de notar que dentro de la categorización para las víctimas y para los acusados se presenta el término "camioneta". Al revisar el diccionario de datos para esta base, este concepto no se encuentra definido; por lo que se hace una suposición respecto a este dato, entendiendo que hace parte del grupo "camion", el cual sí está definido dentro del diccionario del dataset, pero fue escrito de manera diferente por razones humanas.

# Se decide cambiar las ocurrencias de "camioneta" a "camión"
lesiones["victima"].replace("CAMIONETA","CAMION",inplace=True)
lesiones["acusado"].replace("CAMIONETA","CAMION",inplace=True)

# %%
# Se eliminan las columnas de "franja_hora".
lesiones.drop(columns=["franja_hora"],inplace=True)

# %%
lesiones.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 13250 entries, 0 to 23784
# Data columns (total 16 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             13250 non-null  object
#  1   n_victimas     13250 non-null  int64
#  2   aaaa           13250 non-null  int64
#  3   mm             13250 non-null  int64
#  4   dd             13250 non-null  int64
#  5   fecha          13250 non-null  object
#  6   hora           13245 non-null  object
#  7   comuna         12520 non-null  float64
#  8   tipo_calle     9479 non-null   object
#  9   cruce          7028 non-null   object
#  10  longitud       12538 non-null  float64
#  11  latitud        12538 non-null  float64
#  12  victima        13052 non-null  object
#  13  acusado        8497 non-null   object
#  14  participantes  13250 non-null  object
#  15  gravedad       449 non-null    object
# dtypes: float64(3), int64(4), object(9)
# memory usage: 1.7+ MB

# %%
# Para asegurar que los datos se encuentren en el formato de fecha adecuado, se unen los datos ubicados en AÑO [AAAA], MES [MM] y DÍA [DD] para luego convertir a formato de fecha.
lesiones.insert(2,"fecha_2",lesiones["aaaa"].astype(str)+"-"+lesiones["mm"].astype(str)+"-"+lesiones["dd"].astype(str))
lesiones.insert(3,"fecha_revisada",lesiones["fecha_2"].apply(es_fecha))

# Se eliminan las columnas "FECHA" y "fecha_2" y se cambia el nombre de la columna "fecha_revisada" a "FECHA"
lesiones.drop(columns=["fecha","fecha_2"],inplace=True)
lesiones.rename(columns={"fecha_revisada":"fecha"},inplace=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[203], line 3
#       1 # Para asegurar que los datos se encuentren en el formato de fecha adecuado, se unen los datos ubicados en AÑO [AAAA], MES [MM] y DÍA [DD] para luego convertir a formato de fecha.
#       2 lesiones.insert(2,"fecha_2",lesiones["aaaa"].astype(str)+"-"+lesiones["mm"].astype(str)+"-"+lesiones["dd"].astype(str))
# ----> 3 lesiones.insert(3,"fecha_revisada",lesiones["fecha_2"].apply(es_fecha))
#       5 # Se eliminan las columnas "FECHA" y "fecha_2" y se cambia el nombre de la columna "fecha_revisada" a "FECHA"
#       6 lesiones.drop(columns=["fecha","fecha_2"],inplace=True)
#
# NameError: name 'es_fecha' is not defined

# %%
# Se crea la columna "cruce_r" con True/False basado en la presencia de NaN en "cruce".
lesiones.insert(10,'cruce_r', lesiones['cruce'].apply(lambda x: False if pd.isna(x) else True))

# %%
# Se observa el dataframe.
lesiones.head()
# Out:
#                 id  n_victimas      fecha  aaaa  mm  dd      hora  comuna  \
# 0  LC-2019-0000179           1 2019-01-01  2019   1   1  09:00:00    14.0
# 1  LC-2019-0000053           1 2019-01-01  2019   1   1  01:55:00     8.0
# 3  LC-2019-0000079           1 2019-01-01  2019   1   1  02:30:00     7.0
# 4  LC-2019-0000082           4 2019-01-01  2019   1   1  04:30:00     3.0
# 5  LC-2019-0000136           2 2019-01-01  2019   1   1  08:05:00    15.0
#
#   tipo_calle cruce  cruce_r   longitud    latitud   victima acusado  \
# 0        NaN   NaN    False -58.408911 -34.559658  CICLISTA     NaN
# 1        NaN   NaN    False -58.443510 -34.669125      AUTO     NaN
# 3        NaN   NaN    False -58.437425 -34.647349    PEATON     NaN
# 4        NaN   NaN    False -58.398225 -34.604579      AUTO     NaN
# 5        NaN   NaN    False -58.439392 -34.588108      MOTO     NaN
#
#   participantes gravedad
# 0   CICLISTA-SD      NaN
# 1       AUTO-SD      NaN
# 3     PEATON-SD      NaN
# 4       AUTO-SD      NaN
# 5       MOTO-SD      NaN

# %%
lesiones.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 13250 entries, 0 to 23784
# Data columns (total 17 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             13250 non-null  object
#  1   n_victimas     13250 non-null  int64
#  2   fecha          13250 non-null  datetime64[ns]
#  3   aaaa           13250 non-null  int64
#  4   mm             13250 non-null  int64
#  5   dd             13250 non-null  int64
#  6   hora           13245 non-null  object
#  7   comuna         12520 non-null  float64
#  8   tipo_calle     9479 non-null   object
#  9   cruce          7028 non-null   object
#  10  cruce_r        13250 non-null  bool
#  11  longitud       12538 non-null  float64
#  12  latitud        12538 non-null  float64
#  13  victima        13052 non-null  object
#  14  acusado        8497 non-null   object
#  15  participantes  13250 non-null  object
#  16  gravedad       449 non-null    object
# dtypes: bool(1), datetime64[ns](1), float64(3), int64(4), object(8)
# memory usage: 1.7+ MB

# %% [markdown]
# Se guarda la base trabajada

# %%
# Se guarda la base de datos trabajada.
lesiones.to_csv("../Data/Corregidos/lesiones_hechos.csv",index=False,sep=";")

# %%
# Se revisa que la base cargue adecuadamente.
lesiones = pd.read_csv("../Data/Corregidos/lesiones_hechos.csv",sep=";")
lesiones.head()
# Out:
#                 id  n_victimas       fecha  aaaa  mm  dd      hora  comuna  \
# 0  LC-2019-0000179           1  2019-01-01  2019   1   1  09:00:00    14.0
# 1  LC-2019-0000053           1  2019-01-01  2019   1   1  01:55:00     8.0
# 2  LC-2019-0000079           1  2019-01-01  2019   1   1  02:30:00     7.0
# 3  LC-2019-0000082           4  2019-01-01  2019   1   1  04:30:00     3.0
# 4  LC-2019-0000136           2  2019-01-01  2019   1   1  08:05:00    15.0
#
#   tipo_calle cruce  cruce_r   longitud    latitud   victima acusado  \
# 0        NaN   NaN    False -58.408911 -34.559658  CICLISTA     NaN
# 1        NaN   NaN    False -58.443510 -34.669125      AUTO     NaN
# 2        NaN   NaN    False -58.437425 -34.647349    PEATON     NaN
# 3        NaN   NaN    False -58.398225 -34.604579      AUTO     NaN
# 4        NaN   NaN    False -58.439392 -34.588108      MOTO     NaN
#
#   participantes gravedad
# 0   CICLISTA-SD      NaN
# 1       AUTO-SD      NaN
# 2     PEATON-SD      NaN
# 3       AUTO-SD      NaN
# 4       MOTO-SD      NaN

# %% [markdown]
# ### Revisión estadística

# %% [markdown]
# A partir de la base de datos se revisan algunas relaciones.

# %%
# Observemos inicialmente el describe nuevamente de la base de datos.

lesiones.describe()
# Out:
#          n_victimas          aaaa            mm            dd        comuna  \
# count  13250.000000  13250.000000  13250.000000  13250.000000  12520.000000
# mean       1.131547   2020.177811      6.287849     15.465736      8.167891
# std        0.491279      0.782048      3.605438      8.773622      4.668781
# min        1.000000   2019.000000      1.000000      1.000000      1.000000
# 25%        1.000000   2020.000000      3.000000      8.000000      4.000000
# 50%        1.000000   2020.000000      6.000000     15.000000      9.000000
# 75%        1.000000   2021.000000      9.000000     23.000000     12.000000
# max       10.000000   2021.000000     12.000000     31.000000     15.000000
#
#            longitud       latitud
# count  1.253800e+04  1.253800e+04
# mean  -4.650419e+05 -2.770238e+05
# std    5.206570e+07  3.101537e+07
# min   -5.829963e+09 -3.472891e+09
# 25%   -5.847721e+01 -3.463209e+01
# 50%   -5.844159e+01 -3.461093e+01
# 75%   -5.840546e+01 -3.458903e+01
# max   -5.835346e+01 -3.453466e+01

# %%
# Observemos la distribución del número de hechos registrados por el año.

sns.countplot(lesiones,x="aaaa")
plt.title("Número de hechos por año")
plt.xlabel("Año")
plt.ylabel("Conteo")
plt.show()

# %% [markdown]
# En contraposición a lo observado en las base de hechos para homicidios, la tendencia para los datos de lesiones presenta un incremento del número de registro para los años. Si bien, en este caso la muestra presenta datos sólo desde el 2019 hasta el 2021, podría ser importante considerar esta información al momento de revisar la información.

# %%
# Observación de ocurrencias por comuna.
sns.countplot(lesiones,x= "comuna")
plt.title("Prevalencia de hechos por comuna")
plt.show()

# %% [markdown]
# Respecto a la base de hechos para homicidios, se observa que la comuna 1 sigue siendo aquella en la que se presentan más número de hechos. Sin embargo, se observa un incremento en la aparición de la comunca 15 y 14 respecto a la base de homicidios. Esto nos podría indicar que, si bien en las comunas 1, 4 y 9 se presentan mayor número de hechos con homicidios, las comunas 14 y 15 deben también ser tenidas en cuenta para reducir los hechos.
#
# Observemos la proporción de cada una de las comunas a continuación:

# %%
# Proporción de hechos por comuna.
print("Proporción de hechos por comuna")
lesiones["comuna"].value_counts(normalize=True)
# Out:
# Proporción de hechos por comuna
# comuna
# 1.0     0.109265
# 15.0    0.101118
# 4.0     0.081949
# 14.0    0.080511
# 9.0     0.075879
# 3.0     0.070607
# 12.0    0.070128
# 11.0    0.062061
# 13.0    0.059185
# 7.0     0.058866
# 10.0    0.056390
# 5.0     0.054073
# 8.0     0.042732
# 6.0     0.038978
# 2.0     0.038259
# Name: proportion, dtype: float64

# %% [markdown]
# En este caso, la revisión de la proporción nos muestra que el segundo lugar con número de hechos lo toma la comuna 15, siendo la comuna 4 desplazada al tercer lugar, donde la cuarta posición es tomada por la comuna 14 y la quinta por la comuna 9.
#
# Es importante notar que la comuna 3 y 12 también presentan un elevando número de casos, siguiendo muy de cerca a la comuna 9.

# %%
# Proporción por víctima.
print("Proporción por tipo de víctima:")
lesiones["victima"].value_counts(normalize=True)
# Out:
# Proporción por tipo de víctima:
# victima
# MOTO                  0.418403
# CICLISTA              0.169246
# AUTO                  0.155762
# PEATON                0.155225
# TRANSPORTE PUBLICO    0.051946
# CAMION                0.020533
# TAXI                  0.013944
# MOVIL                 0.007662
# MIXTO                 0.003218
# MONOPATIN             0.002145
# OTRO                  0.000996
# UTILITARIO            0.000919
# Name: proportion, dtype: float64

# %% [markdown]
# A diferencia del número de hechos en homicidos, aquí los ciclistas toman una mayor proporción del número de hechos en los cuales son víctima. Esto implicaría que, si bien el son el segundo grupo de víctimas con mayor número de accidentes de tráfico, el número de casos donde se presentan homicidios es mucho menor en comparación a los otros tres grupos con mayor número de accidentes (motos, autos y peatones)
#
# Es de notar que la proporción de accidentes donde la víctima es una moto, es muy similar a la registrada en el dataset de homicidios. Así mismo, la proporción del número de peatones como víctimas en los hechos con homicidio es mayor. Estos dos grupos nos invitarían a hacer una revisión más extendida, ya que la información parece sugerir que son los grupos de víctimas más propensos a sufrir de accidentes fatales.

# %%
# Proporción de hechos por tipo de acusado.
print("Proporción por tipo de acusado")
lesiones["acusado"].value_counts(normalize=True)
# Out:
# Proporción por tipo de acusado
# acusado
# AUTO                  0.546193
# CAMION                0.136519
# TRANSPORTE PUBLICO    0.114746
# MOTO                  0.073555
# TAXI                  0.069554
# OBJETO FIJO           0.032835
# MOVIL                 0.009533
# CICLISTA              0.009062
# UTILITARIO            0.003295
# OTRO                  0.002825
# PEATON                0.001530
# MONOPATIN             0.000353
# Name: proportion, dtype: float64

# %% [markdown]
# En este caso, los tres mayores grupos de acusados para los hechos registrados son autos (54.6% de la muestra), camiones (13,7%) y vehículos de transporte público (11.5%). Los dos primeros puestos son coherentes con lo registrado en la base de hechos con homicidios (donde la categoría "camion" en lesiones, por su definición es similar a la categoría "cargas" en el dataset de homicidios).
#
# En este caso, habría una necesidad de revisión de los hechos causados por pasajeros, ya que no es una categoría que aparezca en el dataset de lesiones, y podría resultar importante contar con esta agregación también en este dataset para comparaciones.
#
# Finalmente, los vehículos de transporte público aparecen como el tercer grupo con mayor proporción como acusados de los accidentes de tráfico registrados. Esto podría ser importante al momento de pensar estrategias para reducir el número de hechos, ya que es una población con la que se puede tener una capacitación más directa, así como un mejor seguimiento; en comparación a los grupos de conductores privados (carros y camiones).
